# %%
# installing spark in colab and creating spark session

# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.0.0/spark-3.0.0-bin-hadoop3.2.tgz
# !tar xf spark-3.0.0-bin-hadoop3.2.tgz
# !pip install -q findspark

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-bin-hadoop3.2"

import findspark
findspark.init()

findspark.find()

from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

sc = spark.sparkContext

# %%
plotSummaries = sc.textFile('/content/plot_summaries.txt')

# %%
moviesMetadata = spark.read.csv('/content/movie.metadata.tsv', sep=r'\t', header=False) # here we get dataframe
movies = moviesMetadata.rdd # converts dataframe to rdd
movieNames = movies.map(lambda row : (row._c0, row._c2)) # maps over rdd
movies = movieNames.collectAsMap()

# %%
summaries = plotSummaries.map(lambda line : line.split('\t')).map(lambda x : (x[0], x[1])) # get key-value tuple pair using maps

# %%
summaries.take(5)
# Out:
# [('23890098',
#   "Shlykov, a hard-working taxi driver and Lyosha, a saxophonist, develop a bizarre love-hate relationship, and despite their prejudices, realize they aren't so different after all."),
#  ('31186339',
#   'The nation of Panem consists of a wealthy Capitol and twelve poorer districts. As punishment for a past rebellion, each district must provide a boy and girl  between the ages of 12 and 18 selected by lottery  for the annual Hunger Games. The tributes must fight to the death in an arena; the sole survivor is rewarded with fame and wealth. In her first Reaping, 12-year-old Primrose Everdeen is chosen from District 12. Her older sister Katniss volunteers to take her place. Peeta Mellark, a baker\'s son who once gave Katniss bread when she was starving, is the other District 12 tribute. Katniss and Peeta are taken to the Capitol, accompanied by their frequently drunk mentor, past victor Haymitch Abernathy. He warns them about the "Career" tributes who train intensively at special academies and almost always win. During a TV interview with Caesar Flickerman, Peeta unexpectedly reveals his love for Katniss. She is outraged, believing it to be a ploy to gain audience support, as "sponsors" may provide in-Games gifts of food, medicine, and tools. However, she discovers Peeta meant what he said. The televised Games begin with half of the tributes killed in the first few minutes; Katniss barely survives ignoring Haymitch\'s advice to run away from the melee over the tempting supplies and weapons strewn in front of a structure called the Cornucopia. Peeta forms an uneasy alliance with the four Careers. They later find Katniss and corner her up a tree. Rue, hiding in a nearby tree, draws her attention to a poisonous tracker jacker nest hanging from a branch. Katniss drops it on her sleeping besiegers. They all scatter, except for Glimmer, who is killed by the insects. Hallucinating due to tracker jacker venom, Katniss is warned to run away by Peeta. Rue cares for Katniss for a couple of days until she recovers. Meanwhile, the alliance has gathered all the supplies into a pile. Katniss has Rue draw them off, then destroys the stockpile by setting off the mines planted around it. Furious, Cato kills the boy assigned to guard it. As Katniss runs from the scene, she hears Rue calling her name. She finds Rue trapped and releases her. Marvel, a tribute from District 1, throws a spear at Katniss, but she dodges the spear, causing it to stab Rue in the stomach instead. Katniss shoots him dead with an arrow. She then comforts the dying Rue with a song. Afterward, she gathers and arranges flowers around Rue\'s body. When this is televised, it sparks a riot in Rue\'s District 11. President Snow summons Seneca Crane, the Gamemaker, to express his displeasure at the way the Games are turning out. Since Katniss and Peeta have been presented to the public as "star-crossed lovers", Haymitch is able to convince Crane to make a rule change to avoid inciting further riots. It is announced that tributes from the same district can win as a pair. Upon hearing this, Katniss searches for Peeta and finds him with an infected sword wound in the leg. She portrays herself as deeply in love with him and gains a sponsor\'s gift of soup. An announcer proclaims a feast, where the thing each survivor needs most will be provided. Peeta begs her not to risk getting him medicine. Katniss promises not to go, but after he falls asleep, she heads to the feast. Clove ambushes her and pins her down. As Clove gloats, Thresh, the other District 11 tribute, kills Clove after overhearing her tormenting Katniss about killing Rue. He spares Katniss "just this time...for Rue". The medicine works, keeping Peeta mobile. Foxface, the girl from District 5, dies from eating nightlock berries she stole from Peeta; neither knew they are highly poisonous. Crane changes the time of day in the arena to late at night and unleashes a pack of hound-like creatures to speed things up. They kill Thresh and force Katniss and Peeta to flee to the roof of the Cornucopia, where they encounter Cato. After a battle, Katniss wounds Cato with an arrow and Peeta hurls him to the creatures below. Katniss sho ...
#  ('20663735',
#   "Poovalli Induchoodan  is sentenced for six years prison life for murdering his classmate. Induchoodan, the only son of Justice Maranchery Karunakara Menon  was framed in the case by Manapally Madhavan Nambiar  and his crony DYSP Sankaranarayanan  to take revenge on idealist judge Menon who had earlier given jail sentence to Manapally in a corruption case. Induchoodan, who had achieved top rank in Indian Civil Service loses the post and Manapally Sudheeran ([[Saikumar  enters the list of civil service trainees. We learn in flashback that it was Ramakrishnan  the son of Moopil Nair , who had actually killed his classmate. Six years passes by and Manapally Madhavan Nambiar, now a former state minister, is dead and Induchoodan, who is all rage at the gross injustice meted out to him - thus destroying his promising life, is released from prison. Induchoodan thwarts Manapally Pavithran  from performing the funeral rituals of Nambiar at Bharathapuzha. Many confrontations between Induchoodan and Manapally's henchmen follow. Induchoodan also falls in love with Anuradha ([[Aishwarya , the strong-willed and independent-minded daughter of Mooppil Nair. Justice Menon and his wife returns back to Kerala to stay with Induchoodan. There is an appearance of a girl named Indulekha ([[Kanaka , who claims to be the daughter of Justice Menon. Menon flatly refuses the claim and banishes her. Forced by circumstances and at the instigation and help of Manapally Pavithran, she reluctantly come out open with the claim. Induchoodan at first thrashes the protesters. But upon knowing the truth from Chandrabhanu his uncle, he accepts the task of her protection in the capacity as elder brother. Induchoodan decides to marry off Indulekha to his good friend Jayakrishnan . Induchoodan has a confrontation with his father and prods him to accept mistake and acknowledge the parentage of Indulekha. Menon ultimately regrets and goes on to confess to his daughter. The very next day, when Induchoodan returns to Poovally, Indulekha is found dead and Menon is accused of murdering her. The whole act was planned by Pavithran, who after killing Indulekha, forces Raman Nair  to testify against Menon in court. In court, Nandagopal Maarar , a close friend of Induchoodan and a famous supreme court lawyer, appears for Menon and manages to lay bare the murder plot and hidden intentions of other party . Menon is judged innocent of the crime by court. After confronting Pavithran and promising just retribution to the crime of killing Indulekha, Induchoodan returns to his father, who now shows remorse for all his actions including not believing in the innocence of his son. But while speaking to Induchoodan, Menon suffers a heart stroke and passes away. At Menon's funeral, Manapally Pavithran arrives to poke fun at Induchoodan and he also tries to carry out the postponed last rituals of his own father. Induchoodan interrupts the ritual and avenges for the death of his sister and father by severely injuring Pavithran. On his way back to peaceful life, Induchoodan accepts Anuradha as his life partner."),
#  ('2231378',
#   'The Lemon Drop Kid , a New York City swindler, is illegally touting horses at a Florida racetrack. After several successful hustles, the Kid comes across a beautiful, but gullible, woman intending to bet a lot of money. The Kid convinces her to switch her bet, employing a prefabricated con. Unfortunately for the Kid, the woman "belongs" to notorious gangster Moose Moran , as does the money. The Kid\'s choice finishes dead last and a furious Moran demands the Kid provide him with $10,000  by Christmas Eve, or the Kid "won\'t make it to New Year\'s." The Kid decides to return to New York to try to come up with the money. He first tries his on-again, off-again girlfriend Brainy Baxter . However, when talk of long-term commitment arises, the Kid quickly makes an escape. He next visits local crime boss "Oxford" Charley , with whom he has had past dealings. This falls through as Charley is in serious tax trouble and does not particularly care for the Kid anyway. As he leaves Charley\'s establishment and is about to give up hope, the Kid notices a cornerside Santa Claus and his kettle. Thinking quickly, the Kid fashions himself a Santa suit and begins collecting donations. This fails as he is recognized by a passing policeman, who remembers his previous underhanded activity well. The Kid lands in court, where he is convicted of collecting for a charity without a license and sentenced to ten days in jail . However, while in court, the Kid learns where his scheme went wrong. After a short stay, Brainy arrives to bail him out. He then sets about restarting his Santa operation, this time with legitimate backing. To this end, he needs a charity to represent and a city license. The kid receives key inspiration when he remembers that Nellie Thursday , a kindly neighborhood resident, has been denied entry to a retirement home because of her jailed husband\'s criminal past as a safecracker. Organizing other small-time New York swindlers and Brainy, who is both surprised and charmed at the Kid\'s apparent goodwill, the Kid converts an abandoned casino  into the "Nellie Thursday Home For Old Dolls". A small group of elderly women and makeshift amenities complete the project. The Kid is able to receive the all-important city license. Now free to collect, the Kid and his compatriots dress as Santa Claus and position themselves throughout Manhattan. The others are unaware that the Kid plans to keep the money for himself to pay off Moran. The scheme is a huge success, netting $2,000 in only a few days. An overjoyed Brainy decides to leave her job as a dancer and look after the "home" full-time until after Christmas. Coincidentally, her employer is none other than "Oxford" Charley, whom Brainy cheerfully informs of the effort. Seeing a potential gold mine, Charley decides to muscle in on the operation. Reasoning that the Nellie Thursday home is "wherever Nellie Thursday is", Charley and his crew kidnap the home\'s inhabitants  and move them to Charley\'s mansion in Nyack. The Kid learns of this when he returns to the home after a late night to find the home deserted and money  gone. Clued in by oversized Oxford footprints in the snow, the Kid and his friends pay Charley a visit. Here, Charley reveals the true nature of the Kid\'s scheme through a phone conversation with Moose Moran. The Kid\'s accomplices are angry and move to confront him, but the Kid manages to slip away. However, Brainy tracks him down outside and voices her disgust at his actions. After a few days of stewing in self-pity , the Kid is surprised to meet Nellie, who has escaped Charley\'s compound. He decides to recover the money, sneaking into Charley\'s home in the guise of an elderly woman. He finds that Charley and his crew are again moving the women, this time to a more secure location. Using the heightened activity to his advantage, the Kid enters Charley\'s office and confronts him. After a brief struggle, the Kid overpowers Charley and makes off with the money, narrowly  ...
#  ('595909',
#   'Seventh-day Adventist Church pastor Michael Chamberlain, his wife Lindy, their two sons, and their nine-week-old daughter Azaria are on a camping holiday in the Outback. With the baby sleeping in their tent, the family is enjoying a barbecue with their fellow campers when a cry is heard. Lindy returns to the tent to check on Azaria and is certain she sees a dingo with something in its mouth running off as she approaches. When she discovers the infant is missing, everyone joins forces to search for her, without success. It is assumed what Lindy saw was the animal carrying off the child, and a subsequent inquest rules her account of events is true. The tide of public opinion soon turns against the Chamberlains. For many, Lindy seems too stoic, too cold-hearted, and too accepting of the disaster that has befallen her. Gossip about her begins to swell and soon is accepted as statements of fact. The couple\'s beliefs are not widely practised in the country, and when the media report a rumour that the name Azaria means "sacrifice in the wilderness" , the public is quick to believe they decapitated their baby with a pair of scissors as part of a bizarre religious rite. Law-enforcement officials find new witnesses, forensics experts, and a lot of circumstantial evidence—including a small wooden coffin Michael uses as a receptacle for his parishioners\' packs of un-smoked cigarettes—and reopen the investigation, and eventually Lindy is charged with murder. Seven months pregnant, she ignores her attorneys\' advice to play on the jury\'s sympathy and appears emotionless on the stand, convincing onlookers she is guilty of the crime of which she is accused. As the trial progresses, Michael\'s faith in his religion and his belief in his wife disintegrate, and he stumbles through his testimony, suggesting he is concealing the truth. In October 1982, Lindy is found guilty and sentenced to life imprisonment with hard labour, while Michael is found guilty as an accessory and given an 18-month suspended sentence. More than three years later, while searching for the body of an English tourist who fell from Uluru, police discover a small item of clothing that is identified as the jacket Lindy had insisted Azaria was wearing over her jumpsuit, which had been recovered early in the investigation. She is immediately released from prison, the case reopened and all convictions against the Chamberlains overturned.')]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string
from nltk.corpus import stopwords
# return words which are not in the list of stopwords(which is list of stopwords and punctuated tokens)
def removeInvalidWords(words):
    stopWords = list(stopwords.words('english'))
    puncs = string.punctuation+' '
    ansList = []
    for word in words:
        word = word.strip(puncs)
        if len(word) == 0:
            continue
        if word not in stopWords:
            ansList.append(word)
    return ansList

# %%
# converts summary to list of words and removes stopwords from them
def removeStopWords(summary):
    words = summary.lower().split(" ")
    newWords = removeInvalidWords(words)
    return newWords

# %%
# maps through summaries and returns list of summary words
summaries = summaries.map(lambda x : (x[0], removeStopWords(x[1])))

# %%
N = summaries.count() # total count of all movie documents

# %%
# calculating tij which is count of ith word in a jth movie document
summary = summaries.flatMapValues(lambda x : x)
tij = summary.map(lambda t : ((t[0], t[1]), 1)).reduceByKey(lambda x, y : x+y)
tij.take(10)
# Out:
# [(('32137084', 'together'), 1),
#  (('19755481', 'lisa'), 7),
#  (('34501845', 'become'), 1),
#  (('31083557', 'kasia'), 1),
#  (('3177319', 'however'), 1),
#  (('61494', 'boarded'), 1),
#  (('204774', 'opera'), 6),
#  (('6004920', 'encounters'), 2),
#  (('6215073', 'city'), 2),
#  (('33383946', 'complications'), 1)]

# %%
# calculating count of a ith word in all the movie documents
ni = summary.distinct().map(lambda t : (t[1], t[0])).reduceByKey(lambda x, y : x+" "+y).map(lambda t : (t[0], len(t[1].split(" "))))
ni = ni.collectAsMap()
ni
# Out:
# {'enters': 2040,
#  'also': 11072,
#  'vaguely': 49,
#  'rope': 438,
#  'path': 641,
#  'luxury': 211,
#  'wife': 7519,
#  'describes': 468,
#  'book': 1568,
#  'arrivals': 24,
#  'says': 4113,
#  'turks': 23,
#  'large': 2705,
#  'sharpened': 16,
#  'becomes': 7972,
#  'position': 1108,
#  'reunion': 332,
#  'women': 2766,
#  'pile': 245,
#  'believes': 2710,
#  'spree': 197,
#  'residents': 486,
#  'died': 2465,
#  'meets': 6491,
#  'authentic': 55,
#  'leaves': 6662,
#  'taught': 314,
#  'serious': 700,
#  'returns': 6325,
#  'enough': 2360,
#  'send': 1230,
#  'sizes—granting': 1,
#  'turn': 3395,
#  'drinking': 929,
#  'battle': 2200,
#  'directly': 491,
#  'approach': 593,
#  'wants': 5527,
#  'even': 5562,
#  'exclusive': 134,
#  'shubhavari': 1,
#  'across': 2692,
#  'mitchell': 174,
#  'leading': 1872,
#  'share': 1411,
#  'well': 5287,
#  'seen': 2835,
#  'frustrated': 788,
#  'finds': 10318,
#  'sole': 320,
#  'join': 2198,
#  'unaware': 1163,
#  'war': 3778,
#  'tales': 187,
#  'grew': 334,
#  'portray': 65,
#  'boss': 1855,
#  'video': 874,
#  'plans': 3152,
#  'spent': 659,
#  'bouquet': 62,
#  'admirer': 108,
#  'threat': 693,
#  'run': 4098,
#  'town': 4394,
#  'distracted': 451,
#  'solution': 285,
#  'host': 438,
#  'make': 7589,
#  'everything': 2331,
#  'selling': 730,
#  'must': 4263,
#  'avoid': 1204,
#  'act': 1836,
#  'babe': 42,
#  'buddha': 58,
#  'remains': 1526,
#  '1995': 61,
#  'meaning': 487,
#  'alien': 523,
#  'two': 13139,
#  'irish': 264,
#  'funeral': 981,
#  'lyssa': 1,
#  'store': 1336,
#  'reunite': 489,
#  'account': 470,
#  'care': 2205,
#  'american': 2674,
#  'stealing': 922,
#  'kneels': 36,
#  'del': 114,
#  'took': 1278,
#  'swears': 265,
#  'friends': 6390,
#  'guard': 1167,
#  'still': 5663,
#  'audience': 1256,
#  'mansion': 740,
#  'interested': 1011,
#  'jungle': 374,
#  'drag': 340,
#  'construction': 564,
#  'imported': 19,
#  'hanging': 722,
#  'laboratory': 313,
#  'sun': 526,
#  'talks': 1006,
#  'verne': 15,
#  'unknown': 1227,
#  'press': 655,
#  'fat': 200,
#  'stating': 567,
#  'fall': 3283,
#  'medical': 959,
#  'challenge': 490,
#  'financial': 760,
#  'star': 1539,
#  'crashes': 927,
#  'become': 5990,
#  'deegan': 3,
#  'several': 4336,
#  'fredric': 6,
#  'owl': 80,
#  'police': 6681,
#  'fact': 2508,
#  'three': 5671,
#  'pin': 170,
#  'head': 4748,
#  'although': 3136,
#  'snow': 418,
#  'locker': 179,
#  'nameb': 1,
#  'inside': 3157,
#  'fixes': 125,
#  'washington': 483,
#  'headed': 482,
#  'blanket': 93,
#  'son': 6483,
#  'hands': 2439,
#  'germans': 318,
#  'paramedics': 61,
#  "arlo's": 3,
#  'ate': 60,
#  'dies': 3355,
#  'earn': 465,
#  'job': 4392,
#  'ss': 133,
#  'studio': 523,
#  'seizes': 187,
#  'boring': 131,
#  'stolen': 1479,
#  'father': 9084,
#  'dumbfounded': 38,
#  'another': 7415,
#  'change': 1889,
#  'prominent': 235,
#  'business': 2679,
#  'killer': 1491,
#  'romantic': 1281,
#  'bargain': 110,
#  'loses': 1857,
#  'officer': 2666,
#  'favourite': 108,
#  'prison': 2273,
#  'holds': 1171,
#  'smoke': 376,
#  'personal': 1404,
#  'less': 810,
#  'bronson': 21,
#  'committed': 1029,
#  'buy': 1322,
#  'used': 2608,
#  'characters': 1460,
#  'uncle': 1452,
#  'could': 3147,
#  'coral': 31,
#  'deformed': 122,
#  'farm': 817,
#  'studies': 486,
#  'body': 3642,
#  'implored': 3,
#  'daisy': 104,
#  'race': 1170,
#  'board': 1260,
#  'ikawa': 1,
#  'instead': 4033,
#  'traffic': 372,
#  'onto': 1847,
#  'descendants': 89,
#  'mason': 121,
#  'acclimate': 5,
#  'underneath': 273,
#  'sebastian': 103,
#  'government': 1561,
#  'ever': 1920,
#  'sword': 533,
#  'state': 1869,
#  'pitched': 31,
#  'follows': 3413,
#  'led': 2202,
#  'kin': 31,
#  'pardons': 32,
#  'know': 3662,
#  'saying': 2454,
#  'kind': 882,
#  'family': 8299,
#  'away': 8716,
#  'anete': 1,
#  'attempt': 3775,
#  'wealthy': 2050,
#  'kidnapper': 87,
#  'ospeo': 1,
#  'show': 3490,
#  'rises': 425,
#  'dolores': 51,
#  'gone': 1822,
#  'paris': 995,
#  'employer/camp': 1,
#  'returning': 1792,
#  'cell': 817,
#  'ignatius': 9,
#  'masturbate': 30,
#  'pereru': 1,
#  'conducting': 132,
#  'trial': 817,
#  'batmobile': 7,
#  'depression': 376,
#  'marines': 132,
#  'smith': 398,
#  'coffee': 395,
#  'master': 946,
#  'jenna': 32,
#  'shows': 4140,
#  'attack': 3233,
#  'live': 3852,
#  'daily': 552,
#  'rifles': 104,
#  'within': 1627,
#  'teach': 639,
#  'didn’t': 54,
#  'dark': 1227,
#  'made': 3603,
#  'hair': 738,
#  'window': 1757,
#  'henchman': 294,
#  'good-natured': 73,
#  'captain': 1680,
#  'vacation': 656,
#  'treason': 115,
#  'rips': 232,
#  'chloe': 65,
#  'canaan': 9,
#  'hating': 45,
#  'accident': 2154,
#  'chemistry': 91,
#  'replaced': 375,
#  'ties': 530,
#  'osborne': 25,
#  'events': 2255,
#  'cosimo': 4,
#  'control': 2231,
#  'moments': 784,
#  'lips': 116,
#  'airport': 822,
#  'love': 10490,
#  '75,000': 7,
#  'york': 2418,
#  'stop': 3794,
#  'birth': 1197,
#  'especially': 969,
#  'backfires': 179,
#  'crying': 564,
#  'beginning': 1330,
#  'assassinations': 32,
#  'target': 609,
#  'showing': 1282,
#  "actor's": 17,
#  'angst': 23,
#  'catering': 63,
#  'drives': 1600,
#  'miserable': 205,
#  'toward': 1068,
#  'beautiful': 2162,
#  'procedure': 139,
#  'noise': 365,
#  "maruthan's": 1,
#  'concert': 450,
#  'insulin': 23,
#  'foil': 152,
#  'luckily': 218,
#  'moon': 456,
#  'demoralize': 7,
#  'situation': 2146,
#  'journalism': 50,
#  'burglary': 76,
#  'diljale': 1,
#  'discontented': 17,
#  'older': 1577,
#  'rescues': 877,
#  'approaching': 448,
#  'score': 279,
#  'seemingly': 1110,
#  'terrorist': 392,
#  'projectiles': 5,
#  'redemption': 110,
#  'closer': 736,
#  'hope': 1245,
#  'greatly': 250,
#  'offers': 2912,
#  'sees': 5290,
#  'prophesied': 24,
#  'notorious': 397,
#  'ask': 1341,
#  'dancing': 803,
#  'outsider': 95,
#  '30': 364,
#  'intelligence': 559,
#  'cash': 677,
#  'proceed': 408,
#  'grant': 377,
#  'exposes': 251,
#  'kader': 11,
#  'ray-ray': 3,
#  'phone': 1831,
#  'criminal': 1245,
#  'revenge': 2397,
#  'reopens': 25,
#  'kraurya': 1,
#  'play': 2414,
#  'vayuputhran': 1,
#  'fails': 1542,
#  'retd.captain': 1,
#  'television': 1050,
#  'reign': 145,
#  'entertain': 119,
#  'manickam': 6,
#  'cleared': 204,
#  'walk': 1387,
#  'dispute': 157,
#  'squander': 10,
#  'reconnect': 79,
#  'reforming': 21,
#  'extended': 246,
#  'sits': 702,
#  'baldwin': 37,
#  'adhered': 2,
#  'lord': 818,
#  'status': 474,
#  'alcoholic': 576,
#  'janov': 1,
#  'inherit': 194,
#  'elegant': 89,
#  'apartment': 2329,
#  'pbs': 5,
#  'wouldn’t': 14,
#  'deranged': 155,
#  'disappears': 753,
#  'warriors': 231,
#  'summoning': 76,
#  'octavia': 6,
#  'renowned': 179,
#  'member': 1524,
#  'cultural': 205,
#  'rogue': 139,
#  'advertising': 261,
#  'rai': 56,
#  'pretext': 122,
#  'relates': 195,
#  'holding': 1217,
#  'closes': 637,
#  'participate': 356,
#  'scenario': 119,
#  'ready': 1279,
#  'supplies': 404,
#  'anna': 356,
#  'held': 1337,
#  '31': 58,
#  'rourke': 8,
#  'whereas': 188,
#  'psychiatrist': 413,
#  'arrest': 1416,
#  'living': 3886,
#  'welcomed': 235,
#  'piece': 884,
#  'jail': 1467,
#  'hole': 762,
#  "natraj's": 1,
#  'allowing': 820,
#  'start': 3308,
#  'sets': 2481,
#  'curtain': 153,
#  'leg': 800,
#  'adolescent': 108,
#  'mystery': 601,
#  'gun': 2540,
#  'old': 6285,
#  '1905': 24,
#  'always': 1908,
#  'outdated': 28,
#  'discussing': 299,
#  'enjoyment': 30,
#  'looking': 2856,
#  'played': 1254,
#  'florida': 296,
#  'malaysian': 23,
#  'bleeper': 1,
#  'truck': 1207,
#  'part': 3499,
#  'wandering': 283,
#  'driver': 1348,
#  'ways': 1367,
#  'stands': 861,
#  'wipe': 141,
#  'group': 4812,
#  'eve': 631,
#  'intense': 363,
#  'supposedly': 535,
#  "family's": 765,
#  'confesses': 1296,
#  'carpathians': 5,
#  'displayed': 122,
#  'catholic': 305,
#  'rabbit': 313,
#  'doyle': 76,
#  'certain': 710,
#  'concoct': 57,
#  'await': 156,
#  'genius': 190,
#  'roles—she': 1,
#  'waterfall': 138,
#  'chinaski': 2,
#  'legal': 402,
#  'embarrassed': 227,
#  'altitude': 43,
#  'accidentally': 2465,
#  "kevin's": 50,
#  'arrests': 334,
#  'enlisted': 122,
#  'dorm': 77,
#  'bleak': 110,
#  'death': 7008,
#  'careful': 123,
#  'african': 446,
#  'villagers': 632,
#  'conclude': 152,
#  'countryside': 454,
#  'kills': 3832,
#  'reunites': 383,
#  'decided': 1005,
#  'jack': 1118,
#  'checks': 338,
#  'william': 628,
#  'arrives': 5194,
#  'suffers': 859,
#  'pretends': 708,
#  'gretchen': 30,
#  'incurable': 30,
#  'door': 2471,
#  'children': 3455,
#  'rumored': 80,
#  'incapable': 88,
#  'came': 1220,
#  'gold': 885,
#  'big': 2228,
#  'case': 2280,
#  'train': 2114,
#  'rich': 1801,
#  'song': 1364,
#  'places': 1040,
#  'wraps': 107,
#  'depict': 50,
#  'fathers': 188,
#  'deserted': 426,
#  'tom': 927,
#  'selects': 93,
#  'robert': 780,
#  'satabdi': 1,
#  'warden': 178,
#  'mistake': 795,
#  "quinn's": 13,
#  'plays': 2007,
#  'results': 1002,
#  'alienates': 55,
#  'visited': 553,
#  'executive': 464,
#  'develops': 1006,
#  'open': 2273,
#  'limousine': 107,
#  '5,000,000': 12,
#  'sounding': 27,
#  'almost': 1841,
#  'recurring': 134,
#  '‘do': 1,
#  'inning': 17,
#  'safe': 1136,
#  'lungs': 44,
#  'cage': 283,
#  'rabbits': 67,
#  'forth': 270,
#  'right': 2452,
#  'waits': 561,
#  'necktie': 7,
#  "booth's": 7,
#  'latimer': 11,
#  'lucas': 100,
#  'lays': 218,
#  'soldiers': 1415,
#  'flawless': 26,
#  'teahouse': 12,
#  'drinks': 588,
#  'clown': 159,
#  'transphasic': 1,
#  'unsure': 234,
#  'stay': 3426,
#  'competition': 605,
#  'suburbs': 106,
#  'newspaper': 1025,
#  '193': 1,
#  'watches': 1186,
#  'captured': 1845,
#  'deferral': 3,
#  'zorro': 17,
#  'rs': 76,
#  'high-speed': 47,
#  'force': 2285,
#  'cancelled': 117,
#  'aristocrat': 105,
#  'new': 10704,
#  'transform': 251,
#  'sorrow': 98,
#  'objects': 420,
#  'engage': 468,
#  'juvenile': 127,
#  'lovers': 737,
#  'judge': 638,
#  'admits': 1389,
#  'hallucinations': 128,
#  'sarafanov': 1,
#  'winner': 270,
#  'forgeries': 6,
#  'convince': 1540,
#  'save': 3340,
#  'orderly': 73,
#  'crosses': 293,
#  'league': 274,
#  'reaches': 1344,
#  'captures': 509,
#  'pocket': 375,
#  'van': 813,
#  'assistant': 1313,
#  'courage': 404,
#  'anti-fascist': 11,
#  'isolate': 29,
#  'minnie': 54,
#  'mad': 649,
#  'pretend': 345,
#  'teachers': 222,
#  'conceived': 74,
#  'rocky': 227,
#  'helmet': 125,
#  "wife's": 561,
#  'guys': 422,
#  'session': 279,
#  'adjusting': 67,
#  'wounds': 659,
#  'baker': 181,
#  'fixated': 29,
#  'heartbreak': 58,
#  'laura': 257,
#  'causes': 1894,
#  'assassins': 219,
#  'manager': 1121,
#  'employers': 100,
#  'legally': 122,
#  "bishop's": 29,
#  'fraternity': 87,
#  'egg': 218,
#  "gisbourne's": 2,
#  'lecter': 5,
#  'simultaneously': 272,
#  'reasoning': 74,
#  'garden': 470,
#  'classical': 123,
#  'maces': 3,
#  'willing': 715,
#  'music': 1716,
#  'ship': 1564,
#  'ollie': 73,
#  'haunting': 127,
#  'cadiz': 4,
#  'medicine': 361,
#  'fumes': 37,
#  'invites': 1530,
#  'priyad': 1,
#  '1964': 61,
#  'shown': 1829,
#  'distance': 672,
#  'recognised': 49,
#  'moving': 1021,
#  'cars': 512,
#  'immune': 72,
#  "cassim's": 2,
#  'uss': 98,
#  'spectators': 84,
#  'scrubs': 13,
#  'leaving': 4526,
#  'oldest': 182,
#  'complex': 430,
#  'overlooking': 108,
#  'hand': 3103,
#  'department': 744,
#  'guilty': 807,
#  'ghastly': 32,
#  'meantime': 710,
#  'brissy': 1,
#  'on-camera': 6,
#  'truth': 2235,
#  'gang': 2442,
#  'timeline': 52,
#  'co-workers': 194,
#  'lines': 567,
#  'instantly': 578,
#  'battles': 350,
#  "film's": 785,
#  'habit': 180,
#  'laser': 116,
#  "ryer's": 1,
#  'foreign': 457,
#  'refuses': 4272,
#  'type': 341,
#  'state-of-the-art': 20,
#  'pushed': 310,
#  'waving': 82,
#  'outa': 1,
#  'released': 1586,
#  'kidnappers': 141,
#  'located': 454,
#  'beauty': 625,
#  'angered': 509,
#  'hanbok': 2,
#  'satisfied': 212,
#  'imposed': 40,
#  'half': 1070,
#  'khurana': 17,
#  'bird': 388,
#  'jwala': 6,
#  'community': 950,
#  'pay': 1939,
#  'seung-beom': 2,
#  'hard-drinking': 24,
#  'organizing': 64,
#  'facing': 466,
#  'dance': 1426,
#  'lot': 1174,
#  'issues': 575,
#  'members': 2110,
#  'silas': 16,
#  'nonchalance': 2,
#  'split': 558,
#  'elliptical': 1,
#  'seemed': 138,
#  'decides': 7357,
#  'including': 3652,
#  'feminine': 75,
#  'trips': 316,
#  'limb': 29,
#  'liked': 158,
#  'remembering': 251,
#  'reelection': 10,
#  'finishing': 222,
#  'launches': 266,
#  'turning': 870,
#  'seclusion': 49,
#  'murdered': 1855,
#  'cottage': 193,
#  'confides': 325,
#  'dragging': 154,
#  'landis': 12,
#  'visions': 294,
#  'whilst': 607,
#  'miserably': 48,
#  'zedoni': 1,
#  'placing': 246,
#  'budding': 141,
#  'couples': 300,
#  'unbeknownst': 443,
#  "sterling's": 3,
#  'deep': 900,
#  'gradual': 25,
#  'guilt': 635,
#  'hail': 68,
#  'm16': 11,
#  'rent': 383,
#  'removed': 429,
#  'print': 102,
#  'toilet': 218,
#  'wookworker': 1,
#  'knowledge': 871,
#  "art's": 6,
#  'adell': 1,
#  'doors': 403,
#  '18-year-old': 68,
#  'abuse': 452,
#  'seekers': 20,
#  'cost': 414,
#  'ill': 961,
#  'medici': 5,
#  'beloved': 500,
#  'mind': 1724,
#  'prize': 439,
#  'vatican': 52,
#  'mentioning': 90,
#  'favors': 95,
#  'sings': 512,
#  'player': 677,
#  'person': 2054,
#  'nosey': 7,
#  'crawling': 77,
#  'sabotage': 294,
#  'previously': 862,
#  'ocean': 654,
#  'clones': 62,
#  'voicing': 12,
#  'told': 2659,
#  'surfing': 74,
#  'occupied': 269,
#  'revolutionary': 233,
#  'mate': 298,
#  'helicopter': 551,
#  'laughing': 371,
#  'leader': 2041,
#  'sinks': 271,
#  'so-called': 102,
#  'confront': 959,
#  'sublimates': 2,
#  'preparing': 716,
#  'expresses': 571,
#  'steps': 872,
#  'lingers': 21,
#  'eros': 6,
#  "opponent's": 21,
#  'maldeneiye': 1,
#  'operations': 295,
#  'transpires': 98,
#  'pulse': 54,
#  'interrupted': 770,
#  "persia's": 3,
#  "kong's": 23,
#  'shooting': 1330,
#  'recover': 658,
#  "ghetto's": 2,
#  'uncovered': 103,
#  'occupiers': 16,
#  'salary': 109,
#  'gesture': 119,
#  'parallel': 197,
#  "irish's": 1,
#  'synopsis': 145,
#  'period': 710,
#  'double': 566,
#  'protagonists': 149,
#  'implication': 55,
#  'learns': 3871,
#  'mecha': 18,
#  'prone': 59,
#  'behalf': 298,
#  'tunnel': 367,
#  'pulls': 1499,
#  'progressive': 49,
#  '5,000': 92,
#  'medicines': 32,
#  'accepted': 510,
#  'subversive': 24,
#  'springer': 14,
#  'social': 1041,
#  'sample': 120,
#  'enlist': 221,
#  'grown': 636,
#  'booth': 194,
#  'pbn': 1,
#  'tropical': 107,
#  'pit': 297,
#  'everett': 36,
#  'assigned': 938,
#  'henry': 610,
#  'nazi': 438,
#  'like': 5364,
#  'jaguar': 41,
#  'मैंने': 1,
#  'activities': 720,
#  'hook': 263,
#  'rainy': 89,
#  'kalyani': 23,
#  'solo': 170,
#  'basterds': 1,
#  'chase': 1757,
#  'eat': 881,
#  'action': 1275,
#  'reading': 738,
#  'unless': 523,
#  'continuously': 125,
#  'engineered': 69,
#  'mercy': 225,
#  'bobby': 297,
#  'pretty': 451,
#  'approaches': 1071,
#  'thief': 619,
#  'barons': 18,
#  'distress': 241,
#  'ledger': 14,
#  'professional': 731,
#  'warning': 710,
#  'wherein': 123,
#  '1,000': 74,
#  'mistress': 551,
#  'environment': 235,
#  'distractions': 25,
#  'fool': 235,
#  'prevents': 264,
#  'rulebook-wielding': 1,
#  'parade': 202,
#  'concentrate': 92,
#  'unnatural': 50,
#  'mf': 1,
#  'possession': 455,
#  'uptight': 68,
#  'continually': 238,
#  'stage': 1279,
#  'carrying': 1031,
#  'texas': 476,
#  'hero': 891,
#  'steal': 1586,
#  'orange': 142,
#  'underlying': 36,
#  'thinks': 2108,
#  "dad's": 107,
#  'scoubidouvitch': 1,
#  'tommy': 322,
#  'win': 1777,
#  'disapprove': 46,
#  'criswell': 3,
#  'duo': 425,
#  'opportunities': 101,
#  'marat': 5,
#  'fear': 1203,
#  'tongue-in-cheek"{{cite': 1,
#  'fascination': 70,
#  'plotting': 202,
#  'shake': 198,
#  'caused': 935,
#  'modelling': 12,
#  'flying': 969,
#  'kept': 864,
#  'liu': 63,
#  'wilson': 270,
#  'maintaining': 96,
#  'ferocity': 10,
#  'devin': 10,
#  'arun': 64,
#  'well-to-do': 56,
#  'spouse': 67,
#  'bear': 699,
#  'leper': 20,
#  'denial': 78,
#  'repeated': 210,
#  'sorrows': 63,
#  'irs': 37,
#  'separated': 706,
#  'planet': 619,
#  'uniform': 287,
#  'money.he': 1,
#  'wreckage': 173,
#  'indulge': 61,
#  'attend': 1029,
#  'lose': 1239,
#  'sabotages': 83,
#  'unnerved': 50,
#  'director': 1234,
#  "johnson's": 30,
#  'minibike': 2,
#  'occurs': 447,
#  'wait': 975,
#  'assassin': 399,
#  'database': 105,
#  'convicted': 401,
#  'let': 2346,
#  'falls': 6274,
#  'loss': 896,
#  'treatise': 5,
#  'walls': 381,
#  'hard-working': 54,
#  'rather': 1741,
#  'register': 90,
#  'guidance': 162,
#  'mounts': 109,
#  'stevens': 87,
#  'quarters': 180,
#  'ann': 251,
#  'gozu': 1,
#  'kat': 39,
#  'assaults': 193,
#  "doc's": 35,
#  'improving': 43,
#  'accident-prone': 8,
#  'gobinda': 1,
#  'feels': 2193,
#  'underwater': 249,
#  'voicemail': 21,
#  'route': 581,
#  'honored': 69,
#  'runner': 105,
#  'workplace': 89,
#  'drowning': 262,
#  'televangelist': 8,
#  'coauthors': 5,
#  'guarantee': 52,
#  'choir': 78,
#  'full': 1850,
#  'perceives': 62,
#  'reception': 238,
#  'daughters': 529,
#  'gullah': 3,
#  'ex-wife': 278,
#  'trainer-parents': 1,
#  'influence': 601,
#  'abubaker': 1,
#  'bulgaria': 18,
#  'thugs': 483,
#  'club': 1341,
#  'states': 2212,
#  'nose': 334,
#  'choices': 128,
#  'chewbacca': 12,
#  'classic': 262,
#  "he'd": 250,
#  'knocked': 697,
#  'seeming': 90,
#  'protesters': 53,
#  'hours': 1112,
#  'useful': 103,
#  'youngest': 347,
#  'assuming': 247,
#  'earning': 224,
#  'cards': 320,
#  'vision': 526,
#  'considers': 516,
#  'manuel': 70,
#  'uneasiness': 8,
#  'thelonious': 2,
#  'ted': 204,
#  'professionals': 42,
#  "station's": 67,
#  'belgian': 56,
#  'kamui': 2,
#  'faust': 13,
#  'polygraph': 5,
#  'unbelievable': 30,
#  'porsche': 45,
#  'novel': 505,
#  'bankruptcy': 87,
#  'religious': 495,
#  'remembers': 660,
#  'manically': 13,
#  'probably': 353,
#  'lila': 48,
#  'quantities': 34,
#  'vows': 704,
#  'consideration': 35,
#  'involves': 610,
#  'oil': 427,
#  'haradhan': 2,
#  'los': 1073,
#  'kanaka': 9,
#  'instrument': 90,
#  'trip': 1894,
#  'outburst': 92,
#  'peters': 55,
#  'vow': 161,
#  'schoolmistress': 4,
#  'fired': 935,
#  'grace': 275,
#  'smithers': 5,
#  'shamelessly': 14,
#  'diagnosis': 53,
#  'vinnie': 36,
#  'russian': 630,
#  'twin': 483,
#  'vincent': 171,
#  'midfield': 1,
#  'prowl': 20,
#  'threatened': 525,
#  'romance': 1014,
#  'shape': 259,
#  'bom': 5,
#  'acceptable': 53,
#  'pop': 309,
#  'official': 573,
#  'meteor': 81,
#  'mood': 212,
#  ...}

# %%
# calculating and saving the results of tf-idf for the dataset
import math
tfIdf = tij
tfIdf = tfIdf.map(lambda x : (x[0], float(x[1]*float(math.log(N/ni[x[0][1]]))))).sortBy(lambda x : -x[1])
tfIdf = tfIdf.collectAsMap()

tfIdf
# Out:
# {('21768047', 'keroro'): 991.503712647511,
#  ('6283620', 'hyun'): 949.5408600838645,
#  ('6283620', 'soo'): 939.2580213502184,
#  ('22175264', 'timmy'): 837.9563369335178,
#  ('15465392', 'lucian'): 822.9354120726825,
#  ('7548602', 'marcellus'): 818.4367606898276,
#  ('4457831', 'morgaine'): 809.6039991199793,
#  ('6283620', 'eun'): 742.9310033533852,
#  ('28443267', 'luk'): 711.5791405531826,
#  ('4969625', 'orry'): 703.0771571305083,
#  ('3926180', 'franklin'): 692.1518727474786,
#  ('11467890', 'sabata'): 687.893177540087,
#  ('11584626', 'hyeon-su'): 671.119104533667,
#  ('15769706', 'vamsi'): 669.2002252019616,
#  ('2650227', 'janie'): 665.4244736118126,
#  ('10619079', 'genocyber'): 660.4664203347199,
#  ('21673015', 'ged'): 651.0703908640374,
#  ('25092646', 'obie'): 637.4103691767776,
#  ('35581515', 'hushpuppy'): 617.8556835389315,
#  ('2065944', 'shogo'): 617.4912951400033,
#  ('3257858', 'gidget'): 614.9407474828836,
#  ('23325348', 'cherie'): 601.0220151998877,
#  ('20887118', 'cavil'): 596.5503151410373,
#  ('1308068', 'goldie'): 592.8570365226665,
#  ('196923', 'napoleon'): 576.3041884584172,
#  ('4673173', 'elina'): 575.9601074317377,
#  ('28173585', 'ned'): 566.6048702523055,
#  ('13899957', 'ilius'): 564.592262544196,
#  ('35958353', 'lio'): 563.6902427064601,
#  ('33194261', 'sparkle'): 549.3773332425806,
#  ('26798950', 'silampa'): 543.2868941463018,
#  ('423019', 'itsuki'): 535.0280269756231,
#  ('17798387', 'noh'): 533.5515309042667,
#  ('9676098', 'gally'): 532.6342099473547,
#  ('9524860', 'amir'): 531.7240181325798,
#  ('1323663', 'merlin'): 523.7527903272685,
#  ('16389361', 'raina'): 522.9678020933028,
#  ('1520023', 'jubei'): 522.7945590534234,
#  ('16898172', 'buford'): 520.8857465065694,
#  ('22712364', 'mitchel'): 517.8959249561318,
#  ('8419530', 'juhn'): 511.3288415494606,
#  ('430788', 'hundert'): 511.3288415494606,
#  ('2852763', 'nalla'): 507.93638793774466,
#  ('16389361', 'aakash'): 507.3275772966526,
#  ('35984240', 'kanji'): 505.07270959398534,
#  ('22846761', 'carty'): 500.6761573505135,
#  ('32573143', 'blair'): 500.02268590023164,
#  ('6506391', 'franz'): 494.40056849769786,
#  ('21768047', 'fuyuki'): 491.1186614048419,
#  ('1634487', 'philipe'): 490.0234731515664,
#  ('12911103', 'pugazh'): 488.01731390097035,
#  ('16897584', 'buford'): 480.81761215991025,
#  ('44366', 'novalee'): 479.3707889526193,
#  ('593921', 'nagiko'): 479.3707889526193,
#  ('35924794', 'binee'): 479.3707889526193,
#  ('22885135', 'hikage'): 479.3707889526193,
#  ('5875943', 'dogen'): 479.3707889526193,
#  ('15465392', 'viktor'): 478.19507664127985,
#  ('15269954', 'mladen'): 478.0577768825832,
#  ('1634280', 'baadshah'): 478.0577768825832,
#  ('872497', 'dantès'): 478.0577768825832,
#  ('29680525', 'danny'): 473.0150409735312,
#  ('21836707', 'roland'): 472.91567582075646,
#  ('5198820', 'alva'): 471.5283461496993,
#  ('3294706', 'belldandy'): 468.7181047536722,
#  ('20053344', 'söfren'): 468.7181047536722,
#  ('27698678', 'kiyomaro'): 468.7181047536722,
#  ('31767008', 'killjoy'): 468.1495236036703,
#  ('6060331', 'loggins'): 468.1495236036703,
#  ('6283620', 'woo'): 464.8771327293463,
#  ('11937073', 'philipp'): 458.5954516933913,
#  ('19231927', 'massie'): 458.5954516933913,
#  ('24777060', 'barzak'): 458.0654205547251,
#  ('33096502', 'caboose'): 456.5948195669873,
#  ('28443267', 'donnie'): 456.48970567342036,
#  ('22816824', 'goemon'): 452.16231432564973,
#  ('34420605', 'izna'): 447.412736355778,
#  ('2502339', 'danila'): 447.412736355778,
#  ('31159789', 'sarny'): 447.412736355778,
#  ('18734158', 'garfield'): 444.10321167280006,
#  ('6277939', 'mi-ju'): 438.21962880903465,
#  ('28082913', 'jw'): 436.7600521568309,
#  ('591309', 'calogero'): 436.7600521568309,
#  ('3610464', 'quirt'): 435.52032237787864,
#  ('17974588', 'genji'): 434.18531175623303,
#  ('6149282', 'pimm'): 429.9332359625543,
#  ('11582167', 'julio'): 428.8860843336856,
#  ('4219204', 'hercules'): 427.27201316171903,
#  ('11584626', 'yoon-hee'): 426.25393254005144,
#  ('25542269', 'macgruber'): 426.10736795788387,
#  ('2852763', 'aras'): 426.10736795788387,
#  ('21411112', 'tolbiac'): 426.10736795788387,
#  ('43307', 'vostrikov'): 426.10736795788387,
#  ('17435954', 'mehek'): 426.10736795788387,
#  ('20529023', 'bu'): 424.724432556273,
#  ('4220745', 'todd'): 421.96393383206805,
#  ('13485985', 'georgia'): 419.7316967858257,
#  ('17842609', 'cord'): 419.247157338452,
#  ('23233139', 'so-hee'): 418.30055477226034,
#  ('28903466', 'mitch'): 417.20755013273936,
#  ('61494', 'marietta'): 416.46346229679494,
#  ('24658454', 'cho-cho'): 415.45468375893677,
#  ('12308598', 'steelhead'): 415.45468375893677,
#  ('142469', 'wigand'): 415.45468375893677,
#  ('15591569', 'gottsman'): 415.45468375893677,
#  ('11103867', 'teru'): 410.8250921419964,
#  ('1931336', 'neal'): 409.6560528804,
#  ('15465392', 'sonja'): 408.5369966483747,
#  ('9022669', 'rohan'): 407.9020683363951,
#  ('10418324', 'madhan'): 407.721152864397,
#  ('10644072', 'bhagwaan'): 404.80199955998967,
#  ('9006288', 'barbarosa'): 404.80199955998967,
#  ('29663404', 'sloane'): 403.6402469346484,
#  ('10831021', 'andrea'): 403.5920672984449,
#  ('11103867', 'ako'): 401.2710202317174,
#  ('9676098', 'yugo'): 401.2710202317174,
#  ('3926180', 'snail'): 400.68134346659184,
#  ('35033607', 'sylvester'): 399.13592485529426,
#  ('3153023', 'haru'): 398.74161283735685,
#  ('10198460', 'nikhil'): 398.41106909995113,
#  ('2160215', 'lupin'): 396.2990072327924,
#  ('2804704', 'scarlett'): 396.1554095357549,
#  ('31635274', 'justin'): 395.74184048615183,
#  ('29195939', 'niamh'): 394.14931536104257,
#  ('21673015', 'ratter'): 394.14931536104257,
#  ('32552640', 'tomoki'): 394.14931536104257,
#  ('23233139', 'eon-joo'): 394.14931536104257,
#  ('1218494', 'atanarjuat'): 394.14931536104257,
#  ('12199287', 'walter'): 393.37056749344663,
#  ('24823991', 'skye'): 392.4546579797933,
#  ('2853254', 'anandan'): 391.8048322451302,
#  ('16389361', 'samir'): 390.8938791169332,
#  ('7151371', 'maggie'): 390.7395018168404,
#  ('4276011', 'goku'): 390.50454819504836,
#  ('12902178', 'dominique'): 389.91290864596664,
#  ('30129615', 'popper'): 389.8806881076378,
#  ('19940419', 'nikko'): 388.9511425941003,
#  ('36425315', 'padme'): 388.4219437170989,
#  ('4410476', 'su'): 386.1255835549129,
#  ('8891457', 'mame'): 385.79591957702667,
#  ('30872649', 'tack'): 384.6540897279282,
#  ('34931488', 'skye'): 384.10455887384023,
#  ('5866831', 'dastan'): 383.49663116209547,
#  ('4881898', 'toorop'): 383.49663116209547,
#  ('31140821', 'ambuli'): 383.49663116209547,
#  ('24786271', 'zinos'): 383.49663116209547,
#  ('45606', 'zorba'): 382.1628764111594,
#  ('3024239', 'jue'): 382.1628764111594,
#  ('7197997', 'baloo'): 381.01976337791876,
#  ('16279840', 'caleb'): 380.90825969581056,
#  ('8109596', 'gant'): 379.7202906028414,
#  ('1323663', 'mab'): 378.46240669871173,
#  ('24301630', 'flint'): 377.69515473953953,
#  ('26328632', 'merliah'): 372.84394696314837,
#  ('2384482', 'miklo'): 372.84394696314837,
#  ('13848220', 'daigo'): 370.77309774703275,
#  ('2301542', 'yuichi'): 370.77309774703275,
#  ('20869430', 'alain'): 370.5204455338502,
#  ('4593920', 'spade'): 369.99577054947144,
#  ('33674932', 'mabel'): 369.6851722955459,
#  ('2688769', 'quigley'): 368.64943426249215,
#  ('24586901', 'havens'): 368.5028696803246,
#  ('29367699', 'skye'): 367.40436066193416,
#  ('10189688', 'charan'): 367.40436066193416,
#  ('543276', 'c.c'): 365.68451009545487,
#  ('10603354', 'hai'): 365.08665064516936,
#  ('3097826', 'redding'): 363.58476372926765,
#  ('5414895', 'cao'): 363.58476372926765,
#  ('12196686', 'reed'): 363.4538609287503,
#  ('957322', 'mathayus'): 363.0547325906014,
#  ('9457255', 'julio'): 362.33479538535505,
#  ('9260315', 'gavanas'): 362.19126276420127,
#  ('3342309', 'nazario'): 362.19126276420127,
#  ('21673015', 'franner'): 362.19126276420127,
#  ('76297', 'dunson'): 362.19126276420127,
#  ('600194', 'holli'): 362.19126276420127,
#  ('10198460', 'radhika'): 362.1178467313243,
#  ('14269859', 'ulises'): 361.389203675261,
#  ('871575', 'ash'): 359.82963113344675,
#  ('7535508', 'jenny'): 359.4961565069166,
#  ('18895191', 'linet'): 358.5433326619374,
#  ('3077127', 'rehan'): 358.5433326619374,
#  ('17828310', 'udayan'): 358.5433326619374,
#  ('5637628', 'panor'): 358.5433326619374,
#  ('32009448', 'lena'): 357.8759554434451,
#  ('2572919', 'edward'): 357.7755190758058,
#  ('8666205', 'sakura'): 355.3971620426727,
#  ('2301542', 'yumi'): 355.12930410765676,
#  ('17139921', 'ah'): 355.05792477223434,
#  ('13899957', 'mace'): 353.8947187443822,
#  ('6645089', 'stewie'): 353.5006606803224,
#  ('945029', 'vitti'): 353.5006606803224,
#  ('20869369', 'manise'): 353.5006606803224,
#  ('16167288', 'shaam'): 353.5006606803224,
#  ('31557', 'tuco'): 353.5006606803224,
#  ('30879026', 'pierce'): 353.29721151723106,
#  ('1976777', 'lecter'): 352.6866051740068,
#  ('1107088', 'miyagi'): 352.6866051740068,
#  ('384141', 'shambu'): 352.6866051740068,
#  ('30623977', 'gabbar'): 352.1228138374338,
#  ('33774863', 'dominik'): 352.1228138374338,
#  ('33674932', 'mariella'): 352.1228138374338,
#  ('6426885', 'cheung'): 352.0883143151436,
#  ('3699869', 'kessie'): 351.53857856525417,
#  ('11439529', 'rens'): 351.53857856525417,
#  ('2186688', 'barnier'): 351.53857856525417,
#  ('27375543', 'gasback'): 351.53857856525417,
#  ('1619410', 'grabelski'): 351.53857856525417,
#  ('21621385', 'abijot'): 351.53857856525417,
#  ('4457831', 'gwenhwyfar'): 351.53857856525417,
#  ('18304705', 'chanfle'): 351.53857856525417,
#  ('15851004', 'mametchi'): 351.53857856525417,
#  ('1941591', 'renko'): 351.53857856525417,
#  ('23856720', 'yuda'): 351.53857856525417,
#  ('1020702', 'esteban'): 351.30762732416,
#  ('2097287', 'norman'): 350.99062953964585,
#  ('15966157', 'lauren'): 349.3887829852358,
#  ('5975925', 'darkrai'): 348.5837956435503,
#  ('5512647', 'simar'): 348.5837956435503,
#  ('23566188', 'golgo'): 348.5837956435503,
#  ('33096502', 'grif'): 348.5837956435503,
#  ('6048196', 'tru'): 348.5837956435503,
#  ('2209027', 'zorg'): 348.5837956435503,
#  ('3326231', 'crewe'): 348.2709619956713,
#  ('25744220', 'dante'): 346.9556066121394,
#  ('31635274', 'lo'): 345.85564258999943,
#  ('11601053', 'morgan'): 345.41957023481086,
#  ('26031039', 'pia'): 344.585955381269,
#  ('19793556', 'zorro'): 344.0567176151987,
#  ('16690320', 'blanca'): 344.0567176151987,
#  ('2507217', 'falstaff'): 343.9465887700435,
#  ('23524192', 'dre'): 343.6433588874938,
#  ('24828951', 'pedro'): 342.8613975132774,
#  ('28443267', 'madam'): 342.8613975132774,
#  ('18465367', 'tobi'): 342.8564239996066,
#  ('25342247', 'e.j'): 342.8564239996066,
#  ('3931502', 'akeelah'): 340.88589436630707,
#  ('25244431', 'chulbul'): 340.88589436630707,
#  ('25896181', 'clélia'): 340.88589436630707,
#  ('10400208', 'klaha'): 340.88589436630707,
#  ('357186', 'balian'): 340.88589436630707,
#  ('31161925', 'merong'): 340.88589436630707,
#  ('29329648', 'pretty-eyed'): 340.88589436630707,
#  ('3374760', 'miyoharu'): 340.88589436630707,
#  ('19141239', 'barsha'): 340.88589436630707,
#  ('17228882', 'peñaranda'): 340.88589436630707,
#  ('1126777', 'boone'): 340.8198804123922,
#  ('330874', 'sandro'): 339.5641879457795,
#  ('29687012', 'pari'): 339.5641879457795,
#  ('8621074', 'jimson'): 338.6242586251631,
#  ('934524', 'jin-seok'): 338.6242586251631,
#  ('93760', 'nomi'): 338.6242586251631,
#  ('27428503', 'boyka'): 338.6242586251631,
#  ('1686720', 'seibei'): 338.6242586251631,
#  ('5725629', 'lansdale'): 338.6242586251631,
#  ('23058629', 'lena'): 337.99395791880926,
#  ('24679315', 'arjun'): 336.46442478912047,
#  ('5856167', 'arjun'): 336.46442478912047,
#  ('4220745', 'alex'): 335.9687179437114,
#  ('14148627', 'lucky'): 335.7392904130468,
#  ('23851782', 'gander'): 334.6001126009808,
#  ('27863441', 'kouga'): 334.3925168597645,
#  ('1487971', 'balto'): 334.3925168597645,
#  ('18664228', 'chrome'): 333.5900341617794,
#  ('2393998', 'ryu'): 332.7122368059063,
#  ('25092646', 'scam'): 332.4417846354331,
#  ('17239276', 'bo'): 331.55294015641414,
#  ('1854000', 'bourne'): 330.85741389588776,
#  ('13679495', 'ro'): 330.85741389588776,
#  ('4179782', 'styles'): 330.8356874055326,
#  ('29542934', 'asuna'): 330.23321016735997,
#  ('9129303', 'witek'): 330.23321016735997,
#  ('20693171', 'lat'): 330.23321016735997,
#  ('9097942', 'quiller'): 330.23321016735997,
#  ('25098571', 'hemel'): 330.23321016735997,
#  ('12003', 'battra'): 330.23321016735997,
#  ('27178030', 'liliom'): 330.23321016735997,
#  ('3408276', 'zinga'): 330.23321016735997,
#  ('4298222', 'clark'): 329.7452677339832,
#  ('163437', 'milo'): 329.6877391213841,
#  ('20053344', 'margarete'): 328.66472160677597,
#  ('14708304', 'chelios'): 328.66472160677597,
#  ('24054967', 'karnan'): 328.66472160677597,
#  ('32552640', 'hiyori'): 328.66472160677597,
#  ('23325348', 'joan'): 328.2540389193006,
#  ('23440490', 'bhosle'): 327.85421499960455,
#  ('10578291', 'gemma'): 326.71110196636386,
#  ('2308701', 'jaguar'): 326.138270215411,
#  ('844325', 'petra'): 326.0171225241391,
#  ('27698678', 'gash'): 325.78322097615586,
#  ('2806165', 'willy'): 325.4774736277781,
#  ('2371819', 'malloy'): 325.36185708072696,
#  ('36229546', 'celeste'): 325.1505950603175,
#  ('26441608', 'daiki'): 324.8384449494855,
#  ('15731217', 'ossi'): 324.8384449494855,
#  ('73422', 'klaatu'): 324.8384449494855,
#  ('555857', 'ivy'): 324.7392929023854,
#  ('17243817', 'shelby'): 322.8192445563552,
#  ('16001951', 'covington'): 322.15063984599595,
#  ('15769706', 'bujji'): 322.15063984599595,
#  ('26861668', 'shaggy'): 321.76302033130844,
#  ('23015014', 'yang'): 321.35864219952475,
#  ('22175264', 'jorgen'): 321.3074656212133,
#  ('10208216', 'tweety'): 320.730011715526,
#  ('17996335', 'yogesh'): 319.58052596841287,
#  ('5564313', 'dease'): 319.58052596841287,
#  ('23576946', 'arkin'): 319.58052596841287,
#  ('11410391', 'kimtilal'): 319.58052596841287,
#  ('28620895', 'govindji'): 319.58052596841287,
#  ('1558966', 'lucario'): 319.58052596841287,
#  ('2506380', 'kripal'): 319.58052596841287,
#  ('6809250', 'dunph'): 319.58052596841287,
#  ('5348407', 'koistinen'): 319.58052596841287,
#  ('20014529', 'rudao'): 319.58052596841287,
#  ('12437827', 'conan'): 319.3801261855957,
#  ('755231', 'bleek'): 318.7051845883888,
#  ('2925273', 'feinstone'): 318.7051845883888,
#  ('35033775', 'twan'): 318.7051845883888,
#  ('934524', 'jin-tae'): 318.7051845883888,
#  ('28903466', 'dave'): 318.633838072491,
#  ('31557', 'blondie'): 318.54332441720476,
#  ('6478729', 'pete'): 318.1358434272606,
#  ('28443267', 'yeung'): 317.78535991379545,
#  ('557036', 'marcello'): 317.78535991379545,
#  ('726161', 'mowgli'): 317.2099783188886,
#  ('22175264', 'darkness'): 316.27614314272523,
#  ('76307', 'orville'): 316.03805401100686,
#  ('28620895', 'kishen'): 315.4216588179368,
#  ('1218494', 'oki'): 315.2843730392065,
#  ('21199699', 'maxim'): 315.20381906829255,
#  ('1355085', 'lyra'): 315.057254486125,
#  ('702217', 'mcelroy'): 315.057254486125,
#  ('6081230', 'bella'): 314.5105148767852,
#  ('213462', 'chow'): 314.07243741356376,
#  ('19267703', 'emmanuelle'): 313.44386579610415,
#  ('35581515', 'wink'): 312.77883419563517,
#  ('710822', 'pinocchio'): 312.77883419563517,
#  ('9022958', 'finn'): 312.2600459509255,
#  ('30496084', 'charu'): 310.37554686804566,
#  ('35320691', 'roger'): 310.3227165363063,
#  ('18878308', 'gabrielle'): 310.116783746409,
#  ('1869084', 'jesus'): 309.9761570896617,
#  ('11827016', 'remy'): 309.84072591595054,
#  ('1430058', 'joe'): 309.21769983002605,
#  ('6892118', 'tuffy'): 308.95366692026283,
#  ('32099336', 'ottway'): 308.9278417694658,
#  ('9260315', 'urrocco'): 308.9278417694658,
#  ('31315579', 'machiche'): 308.9278417694658,
#  ('1955275', 'tapion'): 308.9278417694658,
#  ('9247277', 'yoon-seo'): 308.9278417694658,
#  ('1634487', 'mazamette'): 308.9278417694658,
#  ('1407389', 'anney'): 308.9278417694658,
#  ('694405', 'sethe'): 308.9278417694658,
#  ('161452', 'macreedy'): 308.9278417694658,
#  ('8656796', 'tevye'): 308.9278417694658,
#  ('4113991', 'silus'): 308.9278417694658,
#  ('9260315', 'leyabe'): 308.9278417694658,
#  ('4199566', 'brunhild'): 308.9278417694658,
#  ('4410476', 'su-eun'): 308.9278417694658,
#  ('2560949', 'vallo'): 308.74564757000167,
#  ('3966684', 'beatrix'): 308.74564757000167,
#  ('13573527', 'niccolò'): 308.74564757000167,
#  ('961659', 'hessler'): 308.74564757000167,
#  ('5559871', 'dum'): 308.63673566162134,
#  ('15850590', 'chantal'): 308.63673566162134,
#  ('31800410', 'tabby'): 308.63673566162134,
#  ('2188611', 'ray'): 308.3519160615908,
#  ('35760234', 'fitz'): 307.4703737414418,
#  ('20904222', 'chetan'): 307.4703737414418,
#  ('73930', 'mcteague'): 307.4703737414418,
#  ('7237781', 'chai'): 307.32372359158524,
#  ('30496084', 'ram'): 307.229658572406,
#  ('30385795', 'jar'): 306.54478109490276,
#  ('19145638', 'dougal'): 305.79086464829777,
#  ('29246589', 'els'): 305.79086464829777,
#  ('161880', 'hud'): 305.79086464829777,
#  ('2396120', 'vann'): 305.79086464829777,
#  ('6339198', 'kool'): 305.7303011289275,
#  ('5122793', 'baiju'): 305.7303011289275,
#  ('18993404', 'darrin'): 305.7303011289275,
#  ('667945', 'elisabet'): 305.7303011289275,
#  ('24626370', 'amber'): 305.6861466308727,
#  ('11316134', 'augie'): 305.42719026750285,
#  ('27193568', 'shrek'): 304.7370917462124,
#  ('12481557', 'chitti'): 304.7370917462124,
#  ('11094452', 'juror'): 304.5178210346098,
#  ('24626370', 'thayer'): 304.5178210346098,
#  ('4102452', 'devdas'): 304.3965463779915,
#  ('4908814', 'poirot'): 304.3965463779915,
#  ('573288', 'babe'): 304.26064154920397,
#  ('1443465', 'ian'): 303.56239549088866,
#  ('7237781', 'ah'): 302.4567507319033,
#  ('9677936', 'nibbles'): 302.20776931888656,
#  ('27595410', 'allie'): 302.20776931888656,
#  ('18520285', 'georgina'): 301.89609191810564,
#  ('32301635', 'nan'): 301.6492156864905,
#  ('18459346', 'shaka'): 301.2714408104474,
#  ('4483482', 'liszt'): 301.2714408104474,
#  ('3469003', 'thumbelina'): 301.2714408104474,
#  ('14688795', 'mew'): 301.2714408104474,
#  ('3927698', 'novak'): 300.6875993207178,
#  ('7237781', 'yung'): 300.0634930043541,
#  ('680006', 'mowgli'): 300.0634930043541,
#  ('29837644', 'clutch'): 299.24618913496573,
#  ('33374981', 'nani'): 299.24618913496573,
#  ('12003', 'mothra'): 299.24618913496573,
#  ('8960083', 'palinov'): 298.7861105516145,
#  ('73412', 'thornhill'): 298.7861105516145,
#  ('4235653', 'slevin'): 298.7861105516145,
#  ('22175264', 'eliminators'): 298.7861105516145,
#  ('3737258', 'bung'): 298.7861105516145,
#  ('3294706', 'keiichi'): 298.7861105516145,
#  ('1790734', 'hermie'): 298.7861105516145,
#  ('4673173', 'laverna'): 298.7861105516145,
#  ('6325875', 'duane'): 298.70092312738547,
#  ('27693775', 'ronny'): 298.6211250903311,
#  ('19861657', 'aldous'): 298.42712745492884,
#  ('31272168', 'velan'): 298.42712745492884,
#  ('8776448', 'byung-doo'): 298.2751575705187,
#  ('11347793', 'marji'): 298.2751575705187,
#  ('75984', 'hidetora'): 298.2751575705187,
#  ('7023734', 'doomtrooper'): 298.2751575705187,
#  ('31159789', 'clel'): 298.2751575705187,
#  ('16368206', 'blart'): 298.2751575705187,
#  ('7088713', 'vorelli'): 298.2751575705187,
#  ('16056291', 'rutka'): 298.2751575705187,
#  ('142049', 'anderton'): 298.2751575705187,
#  ('4832313', 'maliss'): 298.2751575705187,
#  ('33194261', 'stix'): 298.2751575705187,
#  ('5094131', 'omri'): 298.2751575705187,
#  ('20109381', 'ga-in'): 298.2751575705187,
#  ('4616225', 'pan'): 298.1005702021865,
#  ('32301635', 'feng'): 297.3456269685403,
#  ('34595521', 'donny'): 297.3109595086825,
#  ('180606', 'matrix'): 297.3109595086825,
#  ('8833565', 'gerda'): 297.1724013413541,
#  ('15828749', 'izzy'): 297.1398924858534,
#  ('7450532', 'sp'): 296.7183086877232,
#  ('16168084', 'sp'): 296.7183086877232,
#  ('31518744', 'bean'): 296.5890925148338,
#  ('2711926', 'odysseus'): 296.52447481047056,
#  ('30470648', 'perseus'): 296.52447481047056,
#  ('919546', 'merrin'): 296.52447481047056,
#  ('441280', 'ridley'): 296.50419416527797,
#  ('22198915', 'holtz'): 296.17622921864853,
#  ('8764756', 'artyom'): 296.17622921864853,
#  ('5089524', 'sikandar'): 296.17622921864853,
#  ('35958353', 'majin'): 296.17622921864853,
#  ('1878054', 'tonny'): 296.17622921864853,
#  ('23123057', 'fanfan'): 296.17622921864853,
#  ('26293600', 'jamadagni'): 296.17622921864853,
#  ('28732628', 'sae'): 296.17622921864853,
#  ('870946', 'bourne'): 296.0303176963206,
#  ('2324980', 'rane'): 295.9410867563807,
#  ('13040946', 'liam'): 294.66488014204214,
#  ('2687974', 'fei'): 294.6341176472698,
#  ('6478729', 'scott'): 293.816519121611,
#  ('19231927', 'claire'): 293.7486959392707,
#  ('12199287', 'chris'): 293.32855831680337,
#  ('13137113', 'bobby'): 292.5781715485194,
#  ('9264215', 'dewey'): 292.4797992829927,
#  ('30010383', 'shivers'): 292.41051608072837,
#  ('1131021', 'elektra'): 292.41051608072837,
#  ('30181744', 'niko'): 292.2534687083567,
#  ('573288', 'esme'): 291.4902503470868,
#  ('872441', 'rambo'): 291.15845429348013,
#  ('6017841', 'orin'): 291.15845429348013,
#  ('12139125', 'ave'): 291.15845429348013,
#  ('29680525', 'anya'): 291.15845429348013,
#  ('5461236', 'madonna'): 290.99078163576496,
#  ('11966731', 'andrew'): 290.78060615372345,
#  ('7151371', 'jorge'): 290.7171477359682,
#  ('1343342', 'ben-hur'): 289.3838811684158,
#  ('2065944', 'eiji'): 288.9176124152054,
#  ('8896262', 'spider-man'): 288.9176124152054,
#  ('8312012', 'labu'): 288.82657353322736,
#  ('14725310', 'saigo'): 288.82657353322736,
#  ('438548', 'blackadder'): 288.82657353322736,
#  ('19755481', 'susy'): 288.82657353322736,
#  ('11064746', 'nicky'): 288.56694401589976,
#  ('254274', 'kane'): 288.1520942292086,
#  ('142481', 'satine'): 287.6224733715716,
#  ('1198597', 'stachel'): 287.6224733715716,
#  ('2548068', 'kham'): 287.6224733715716,
#  ('13444065', 'iht'): 287.6224733715716,
#  ('15002256', 'kyaw'): 287.6224733715716,
#  ('33160508', 'bangja'): 287.6224733715716,
#  ('6809623', 'dheena'): 287.6224733715716,
#  ('2093621', 'jefty'): 287.6224733715716,
#  ('8077187', 'drishti'): 287.6224733715716,
#  ('7738646', 'fak'): 287.6224733715716,
#  ('35320691', 'clas'): 287.6224733715716,
#  ('4492505', 'flyora'): 287.6224733715716,
#  ('15002256', 'thant'): 287.6224733715716,
#  ('49696', 'freder'): 287.6224733715716,
#  ('2184458', 'djay'): 287.6224733715716,
#  ('16881835', 'oskar'): 287.32354364642885,
#  ('7320866', 'léopold'): 287.25808497264336,
#  ('4673182', 'rapunzel'): 287.25808497264336,
#  ('619728', 'rapunzel'): 287.25808497264336,
#  ('201553', 'romy'): 287.25808497264336,
#  ('2773221', 'tigger'): 287.2055603188844,
#  ('31083557', 'ava'): 287.2055603188844,
#  ('42293', 'prewitt'): 286.62215730836954,
#  ('24738759', 'rabi'): 286.62215730836954,
#  ('945029', 'sobel'): 286.62215730836954,
#  ('20223641', 'soren'): 286.62215730836954,
#  ('5419425', 'monty'): 286.60979770323604,
#  ('12725443', 'bolton'): 286.0068239224159,
#  ('26100368', 'medina'): 286.0068239224159,
#  ('17798387', 'yoo'): 285.87221422056837,
#  ('245515', 'laura'): 285.80205438690507,
#  ('10619079', 'elaine'): 285.72724908584667,
#  ('4120837', 'toad'): 285.65321935468194,
#  ('18716405', 'cara'): 285.2050731318842,
#  ('9006288', 'karl'): 285.19621542844635,
#  ('3417500', 'carlo'): 284.59169969345555,
#  ('10831021', 'daniel'): 284.0197867300948,
#  ('2460704', 'pokémon'): 283.6834371614633,
#  ('12118683', 'augusta'): 283.6834371614633,
#  ('3022675', 'urquhart'): 283.5495913510093,
#  ('33096502', 'sarge'): 283.0707194519946,
#  ('742453', 'cale'): 282.91700768981957,
#  ('1814329', 'skip'): 282.17959039229464,
#  ('2892393', 'kim'): 282.06028277960337,
#  ('8048017', 'pang'): 281.50095077607165,
#  ('1634487', 'irma'): 281.50095077607165,
#  ('2452459', 'chan'): 281.4945199272463,
#  ('20014529', 'mona'): 280.5447955169658,
#  ('25521383', 'hou'): 280.3406348819028,
#  ('14573581', 'spruce'): 280.3406348819028,
#  ('23123057', 'alexandre'): 279.78074458678486,
#  ('13249791', 'baxter'): 279.3392406526887,
#  ('26847108', 'naruto'): 279.0301675131589,
#  ('1591226', 'swan'): 278.9040004867185,
#  ('2110246', 'katelin'): 278.8670365148402,
#  ('1370478', "d'amour"): 278.8670365148402,
#  ('11103867', 'nimura'): 278.8670365148402,
#  ('17203681', 'edy'): 278.8670365148402,
#  ('4564324', 'azumi'): 278.8670365148402,
#  ('20759694', 'singaperumal'): 278.8670365148402,
#  ('13365023', 'duca'): 278.8670365148402,
#  ('8980330', 'wall-e'): 278.8670365148402,
#  ('24952483', 'taz'): 278.61676959653704,
#  ('16204877', 'skeeter'): 278.61676959653704,
#  ('8719021', 'petros'): 277.99169513481615,
#  ('7651220', 'jesus'): 277.90965808038635,
#  ('294520', 'beverly'): 277.8906323011,
#  ('12138219', 'marnie'): 277.70443667140927,
#  ('6283620', 'tae'): 277.70443667140927,
#  ('80523', 'kris'): 277.4968279121036,
#  ('129331', 'loretta'): 277.4968279121036,
#  ('5587473', 'aladdin'): 277.4968279121036,
#  ('13198130', 'sonia'): 277.382152314673,
#  ('6219956', 'zach'): 277.1954199342952,
#  ('30311716', 'rodrick'): 277.06808539809055,
#  ('33590333', 'driss'): 277.06808539809055,
#  ('11408406', 'ismaël'): 277.06808539809055,
#  ('18634533', 'mcdonagh'): 276.9697891726245,
#  ('9105523', 'riyo'): 276.9697891726245,
#  ('558578', 'celliers'): 276.9697891726245,
#  ('898561', 'antwone'): 276.9697891726245,
#  ('11455154', 'otilia'): 276.9697891726245,
#  ('508458', 'phoolan'): 276.9697891726245,
#  ('742453', 'drej'): 276.9697891726245,
#  ('20485147', 'ilyoung'): 276.9697891726245,
#  ('25584574', 'jongman'): 276.9697891726245,
#  ('296252', 'pikul'): 276.9697891726245,
#  ('5259161', 'gang-du'): 276.9697891726245,
#  ('29785', 'goodspeed'): 276.9697891726245,
#  ('11387538', 'chirin'): 276.9697891726245,
#  ('2408687', 'redferne'): 276.9697891726245,
#  ('20777420', 'wikus'): 276.9697891726245,
#  ('14899108', 'dren'): 276.9697891726245,
#  ('1924012', 'skellen'): 276.9697891726245,
#  ('3433026', 'arren'): 276.9697891726245,
#  ('2964301', 'xiaochun'): 276.9697891726245,
#  ('28147804', 'kelu'): 276.9697891726245,
#  ('8048149', 'vidyadharan'): 276.9697891726245,
#  ('31800410', 'anora'): 276.9697891726245,
#  ('469932', 'robbo'): 276.9697891726245,
#  ('1854612', 'casper'): 276.8447580205036,
#  ('24154973', 'su'): 276.8447580205036,
#  ('24301630', 'kirk'): 276.3671089342769,
#  ('32144390', 'griffith'): 275.5564990568277,
#  ('29664578', 'poe'): 275.5564990568277,
#  ('16430476', 'mist'): 275.55520121513354,
#  ('32034910', 'basanti'): 275.55327049645064,
#  ('30873849', 'hitler'): 275.5510321222218,
#  ('543276', 'hillary'): 275.05090984091913,
#  ('67442', 'orin'): 274.98298461050905,
#  ('171026', 'cady'): 274.6886666212903,
#  ('76617', 'scottie'): 274.6886666212903,
#  ('27953573', 'carmen'): 274.446328830595,
#  ('27193032', 'brant'): 274.3437650325523,
#  ('19145638', 'buxton'): 274.3437650325523,
#  ('36415448', 'droopy'): 274.3437650325523,
#  ('948608', 'dani'): 273.8938234040522,
#  ('31024173', 'meyers'): 273.68147992118077,
#  ('5331654', 'sarah'): 273.63182019299546,
#  ('6196826', 'silver'): 273.3496122457564,
#  ('9155539', 'palmer'): 272.41343167266376,
#  ('30299686', 'kamen'): 272.2191028411961,
#  ('31315579', 'angela'): 272.08807078502196,
#  ('26425120', 'phineas'): 271.6809354367826,
#  ('8419530', 'kim'): 271.6136056396181,
#  ('24717406', 'rowley'): 271.29738859538986,
#  ('34004383', 'spector'): 271.29738859538986,
#  ('11467890', 'stengel'): 271.29738859538986,
#  ('3861685', 'huo'): 271.29738859538986,
#  ('13137113', 'cissy'): 271.29738859538986,
#  ('1979808', 'kazuya'): 271.29738859538986,
#  ('8448026', 'jarrod'): 271.29738859538986,
#  ('3257858', 'abby'): 271.2817874150167,
#  ('2522220', 'beck'): 270.99495017561435,
#  ('12668580', 'luther'): 270.99495017561435,
#  ('6426885', 'ho'): 270.72647925914055,
#  ('2576917', 'evan'): 270.62537315746874,
#  ('323715', 'achilles'): 270.61883938864605,
#  ('1438595', 'scully'): 270.57470789154803,
#  ('171026', 'bowden'): 270.57470789154803,
#  ('314406', 'bennie'): 270.57470789154803,
#  ('17636563', 'paxton'): 270.1175559267261,
#  ('1384107', 'creeper'): 269.90999554664523,
#  ('18717177', 'shrek'): 269.90999554664523,
#  ('2180950', 'milly'): 269.7885826923229,
#  ('15079534', 'napoleon'): 269.75940736351447,
#  ('5125674', 'misty'): 269.6987732233919,
#  ('34287962', 'nate'): 269.6855686458854,
#  ('26861668', 'velma'): 269.55936965154297,
#  ('2301374', 'beauregard'): 269.53665912225017,
#  ('1842419', 'karla'): 269.53665912225017,
#  ('442308', 'noodles'): 269.08669326956937,
#  ('5434141', 'wal'): 268.90749949645306,
#  ('23587009', 'larnell'): 268.90749949645306,
#  ('20533949', 'dingledong'): 268.90749949645306,
#  ('26536541', 'bonin'): 268.90749949645306,
#  ('2478590', 'bozz'): 268.90749949645306,
#  ('3120202', 'bfg'): 268.90749949645306,
#  ('3754368', 'eun-jin'): 268.90749949645306,
#  ('3256994', 'jacey'): 268.90749949645306,
#  ('1974799', 'rikako'): 268.90749949645306,
#  ('2396904', 'jess'): 268.8343426489108,
#  ('3500965', 'choi'): 268.7678792468878,
#  ('15286558', 'ayers'): 268.72530529698895,
#  ('13485985', 'jas'): 268.72530529698895,
#  ('61494', 'warrington'): 268.72530529698895,
#  ('15465392', 'lycans'): 268.72530529698895,
#  ('35255529', 'bittu'): 268.72530529698895,
#  ('286830', 'scamp'): 268.72530529698895,
#  ('20904181', 'ravi'): 268.62780999153824,
#  ('2634920', 'ling'): 268.0576192146267,
#  ('1217079', 'pran'): 267.9232462080487,
#  ('7768616', 'cesar'): 267.6171014668402,
#  ('5579823', 'adrian'): 267.5475423699822,
#  ('22644547', 'oliver'): 267.5266400547874,
#  ('26346721', 'vijay'): 267.5266400547874,
#  ('6954737', "j'onn"): 267.51401348781155,
#  ('24922498', 'loong'): 267.51401348781155,
#  ('15002256', 'zin'): 267.51401348781155,
#  ('6349064', 'hibiki'): 267.51401348781155,
#  ('24051028', 'stockdale'): 267.51401348781155,
#  ('1747692', 'altaaf'): 267.51401348781155,
#  ('16187144', 'cooney'): 267.51401348781155,
#  ('1565282', 'broly'): 267.51401348781155,
#  ('4944673', 'leone'): 267.2031713904976,
#  ('10109051', 'clint'): 267.09178879509216,
#  ('6071715', 'mikey'): 266.57372549038695,
#  ('5246741', 'sivagiri'): 266.3171049736774,
#  ('204774', 'douzi'): 266.3171049736774,
#  ('20461830', 'hong-rim'): 266.3171049736774,
#  ('14700543', 'ayyu'): 266.3171049736774,
#  ('5590914', 'rawhead'): 266.3171049736774,
#  ('18678217', 'kym'): 266.3171049736774,
#  ('26865950', 'naritsugu'): 266.3171049736774,
#  ('26600911', 'ladya'): 266.3171049736774,
#  ('9215059', 'ralls'): 266.3171049736774,
#  ('15002508', 'thit'): 266.3171049736774,
#  ('2378208', 'tellis'): 266.3171049736774,
#  ('171047', 'merivel'): 266.3171049736774,
#  ('15672797', 'bashan'): 266.3171049736774,
#  ('21654938', 'cleatus'): 266.3171049736774,
#  ('1634487', 'moréno'): 266.3171049736774,
#  ('3225410', 'dae-jun'): 266.3171049736774,
#  ('3595521', 'jin-a'): 266.3171049736774,
#  ('2952273', 'diabolik'): 266.3171049736774,
#  ('25664434', 'majka'): 266.3171049736774,
#  ('6457380', 'vorian'): 266.3171049736774,
#  ('10153756', 'vrinks'): 266.3171049736774,
#  ('2528212', 'garrigan'): 266.3171049736774,
#  ('3185575', 'celie'): 266.3171049736774,
#  ('2663035', 'ksc2-303'): 266.3171049736774,
#  ('2080169', 'josie'): 266.28566164282853,
#  ('967174', 'camilla'): 266.28566164282853,
#  ('76383', 'moses'): 266.13766929586205,
#  ('18735140', 'gen'): 266.13766929586205,
#  ('10208216', 'sylvester'): 266.0906165701962,
#  ('731501', 'stevens'): 266.031371452578,
#  ('28444122', 'chico'): 265.9170869574526,
#  ('21015273', 'hubie'): 265.82774189157124,
#  ('4279572', 'dougie'): 265.82774189157124,
#  ('55325', 'quaid'): 265.82774189157124,
#  ('2480188', 'zac'): 265.82774189157124,
#  ('23233139', 'yoo-jin'): 265.82774189157124,
#  ('9597495', 'mame'): 265.77052237528505,
#  ('29329648', 'chicago'): 265.37174019091003,
#  ('1501461', 'otis'): 265.0933003284779,
#  ('2139989', 'hollis'): 264.8465039859396,
#  ('68082', 'wilbur'): 264.77853558678277,
#  ('22059060', 'yoko'): 264.6574610956073,
#  ('7154803', 'toulon'): 264.44968668795065,
#  ('3534336', 'marc'): 264.3676547618013,
#  ('8526754', 'carrie'): 263.76023624461055,
#  ('22644547', 'dexter'): 263.68964753602705,
#  ('1576720', 'kane'): 263.62851174161636,
#  ('11783565', 'aldo'): 263.1016494056281,
#  ('6415441', 'pappu'): 263.1016494056281,
#  ('5079650', 'bean'): 262.88578654723904,
#  ('16881835', 'eli'): 262.88578654723904,
#  ('30201005', 'hoover'): 262.2739812825824,
#  ('29258343', 'takuma'): 262.25414230887685,
#  ('5672172', 'ittō'): 262.25414230887685,
#  ('5238193', 'keith'): 262.2487142159019,
#  ('27339480', 'cao'): 262.11924826993715,
#  ('75255', 'kemp'): 262.0803374725423,
#  ('6652508', 'macbeth'): 261.3688815730911,
#  ('10249080', 'édith'): 261.2032214967535,
#  ('525314', 'shrek'): 261.2032214967535,
#  ('5523710', 'jacinto'): 261.2032214967535,
#  ('454223', 'andie'): 261.2032214967535,
#  ('1809543', 'nasir'): 261.2032214967535,
#  ('7764053', 'flynn'): 261.0219925560802,
#  ('2895474', 'lei'): 260.33636546336555,
#  ('23316260', 'ryder'): 260.18329309276135,
#  ('3024239', 'yuan'): 260.18329309276135,
#  ('1407389', 'bone'): 260.130448166926,
#  ('2182638', 'nathalie'): 260.04315073134137,
#  ('24658454', 'pinkerton'): 260.04315073134137,
#  ('6457380', 'jason'): 260.01014097127916,
#  ('2821645', 'iris'): 259.84459537228554,
#  ('16056291', 'strachey'): 259.45891545916174,
#  ('5148040', 'kagome'): 259.45891545916174,
#  ('11893755', 'mccandless'): 258.9479624780659,
#  ('11582167', 'ligaya'): 258.9479624780659,
#  ('17405162', 'sang-hyun'): 258.9479624780659,
#  ('7195862', 'xiaoshuai'): 258.9479624780659,
#  ('2685420', 'kalidasa'): 258.9479624780659,
#  ('23913058', 'reisman'): 258.9479624780659,
#  ('3374673', 'yorga'): 258.9479624780659,
#  ('6219438', 'chea'): 258.9479624780659,
#  ('1411408', 'kleinman'): 258.9479624780659,
#  ('2260396', 'vinny'): 258.8530722845445,
#  ('33374981', 'bindu'): 258.8530722845445,
#  ('29865278', 'kishen'): 258.8075149275379,
#  ('6843857', 'magnus'): 258.6774998816049,
#  ('6446995', 'oz'): 258.4659678202659,
#  ('12993849', 'fisher'): 258.13499026255766,
#  ('678080', 'fuad'): 257.9599415775326,
#  ('1930290', 'barbarella'): 257.9599415775326,
#  ('20869430', 'manise'): 257.9599415775326,
#  ('2572851', 'beowulf'): 257.9599415775326,
#  ('2396634', 'barnabas'): 257.9599415775326,
#  ('155997', 'tre'): 257.9599415775326,
#  ('10495987', 'raju'): 257.9451254979516,
#  ('14193289', 'millie'): 257.62235894930217,
#  ('5273926', 'aryan'): 257.62235894930217,
#  ('18410798', 'tabitha'): 257.1972797180178,
#  ('4345625', 'pocahontas'): 257.1972797180178,
#  ('23941382', 'theseus'): 257.1972797180178,
#  ('18373306', 'hulk'): 257.09581935001853,
#  ('2804704', 'rhett'): 256.9668171618522,
#  ('5580971', 'thumbelina'): 256.9668171618522,
#  ('1623960', 'ennis'): 256.9668171618522,
#  ('105972', 'madeline'): 256.74714889298315,
#  ('25238567', 'cheng'): 256.54765227591366,
#  ('10620253', 'ranbir'): 256.4360598186188,
#  ('13485985', 'robbie'): 256.4307234466137,
#  ('3032361', 'dupree'): 255.89845671061047,
#  ('32537784', 'hanumant'): 255.6644207747303,
#  ('9676098', 'zalem'): 255.6644207747303,
#  ('9907431', 'soultaker'): 255.6644207747303,
#  ('6506391', 'mieze'): 255.6644207747303,
#  ('4457831', 'morgause'): 255.6644207747303,
#  ('43307', 'polenin'): 255.6644207747303,
#  ('1107088', 'chozen'): 255.6644207747303,
#  ('25664434', 'ania'): 255.6644207747303,
#  ('13444065', 'maek'): 255.6644207747303,
#  ('375183', 'vassili'): 255.6644207747303,
#  ('13682670', 'kuchisake'): 255.6644207747303,
#  ('13310698', 'temüjin'): 255.6644207747303,
#  ('33509716', 'jenko'): 255.6644207747303,
#  ('35958353', 'cybertrons'): 255.6644207747303,
#  ('30623977', 'siddhappa'): 255.6644207747303,
#  ('1463386', 'sukhov'): 255.6644207747303,
#  ('1944643', 'xan'): 255.6644207747303,
#  ('33160508', 'mong-ryong'): 255.6644207747303,
#  ('28732628', 'kouhei'): 255.6644207747303,
#  ('31315579', 'graci'): 255.6644207747303,
#  ('4760936', 'dormer'): 255.6644207747303,
#  ('9513043', 'zohan'): 255.6644207747303,
#  ('18204467', 'jacquou'): 255.6644207747303,
#  ('6392570', 'gigot'): 255.6644207747303,
#  ('31727546', 'maruge'): 255.6644207747303,
#  ('8775362', 'eddie'): 255.47971208237712,
#  ('2913859', 'sean'): 255.06606368599304,
#  ('1411169', 'andrei'): 254.98859291362174,
#  ('5158963', 'amos'): 254.98491108038073,
#  ('15670779', 'lily'): 254.59575778039567,
#  ('18895191', 'godfrey'): 254.3720922527616,
#  ('23015014', 'lynne'): 254.22828793103633,
#  ('6835148', 'dawg'): 254.22828793103633,
#  ('28370864', 'dwayne'): 254.1374325323711,
#  ('20869430', 'cécile'): 253.6637886483263,
#  ('9362760', 'ang'): 253.6637886483263,
#  ('993791', 'hitler'): 253.50694955244404,
#  ('6014008', 'patterson'): 253.30280323954068,
#  ('22098183', 'zamora'): 253.21089602236384,
#  ('27369264', 'ip'): 253.21089602236384,
#  ('1743227', 'valjean'): 253.21089602236384,
#  ('5671088', 'ittō'): 253.21089602236384,
#  ('6469252', 'swagger'): 253.21089602236384,
#  ('4409955', 'adhi'): 253.21089602236384,
#  ('2862407', 'stavros'): 253.21089602236384,
#  ('1376388', 'smallpox'): 253.20110402393198,
#  ('326242', 'yuji'): 252.49644744686168,
#  ('605939', 'tetsuo'): 252.49644744686168,
#  ('733901', 'monty'): 252.48958369094603,
#  ('465470', 'moses'): 252.48958369094603,
#  ('23281512', 'di'): 252.35515108373647,
#  ('4410476', 'ho'): 252.26785567329006,
#  ('33899408', 'ashok'): 251.83901489030012,
#  ('11414473', 'jamal'): 251.41598047147085,
#  ('5273390', 'max'): 251.12502096191338,
#  ('1164551', 'brigitte'): 251.0693381203812,
#  ('13626881', 'naidu'): 251.0693381203812,
#  ('28823872', 'leon'): 250.92347293754742,
#  ('4899791', 'carrie'): 250.89388325706858,
#  ('24211707', 'maynard'): 250.71978008605234,
#  ('33194261', 'satin'): 250.50297317859147,
#  ('534812', 'chucky'): 250.50297317859147,
#  ('746845', 'gabe'): 250.46618231182154,
#  ('35924794', 'amir'): 250.22306735650815,
#  ('4277421', 'sunder'): 250.22306735650815,
#  ('1488066', 'humbert'): 250.19252562133454,
#  ('635989', 'kovak'): 250.19252562133454,
#  ('5148040', 'inuyasha'): 250.19252562133454,
#  ('182737', 'thackeray'): 250.19252562133454,
#  ('32362473', 'gosei'): 250.19252562133454,
#  ('2886036', 'ricky'): 249.62177630664962,
#  ('4179782', 'blake'): 249.33133847657484,
#  ('2121919', 'kong'): 249.32705431210908,
#  ('2399430', 'virgil'): 249.2169061955498,
#  ('13656791', 'matool'): 248.98842545967875,
#  ('2307251', 'ambar'): 248.98842545967875,
#  ('4673182', 'gothel'): 248.98842545967875,
#  ('33160508', 'chunhyang'): 248.98842545967875,
#  ('36147846', 'helge'): 248.98842545967875,
#  ('20570407', 'megamind'): 248.98842545967875,
#  ('24828951', 'tucita'): 248.98842545967875,
#  ('35958353', 'zarak'): 248.98842545967875,
#  ('18579324', 'guilala'): 248.98842545967875,
#  ('672934', 'jobe'): 248.98842545967875,
#  ('33382022', 'sawako'): 248.98842545967875,
#  ('4209429', 'zurg'): 248.98842545967875,
#  ('4908814', 'arlena'): 248.98842545967875,
#  ('34482077', 'zoé'): 248.98842545967875,
#  ('1706423', 'temujin'): 248.98842545967875,
#  ('27863441', 'rekka'): 248.98842545967875,
#  ('18392617', 'garou'): 248.98842545967875,
#  ('2594501', 'tumak'): 248.98842545967875,
#  ('15672797', 'hargraves'): 248.98842545967875,
#  ('68092', 'gittes'): 248.98842545967875,
#  ('34420605', 'kabir'): 248.89630941824433,
#  ('692661', 'carlito'): 248.62403706075054,
#  ('12555863', 'demarco'): 248.62403706075054,
#  ('9524860', 'hassan'): 248.58879272140382,
#  ('71473', 'martins'): 248.42243294928696,
#  ('5569730', 'dominic'): 248.40676481101886,
#  ('30093517', 'clapton'): 248.40586966725363,
#  ('35958353', 'galvatron'): 248.40586966725363,
#  ('28385798', 'nascimento'): 248.40586966725363,
#  ('6361585', 'richthofen'): 248.40586966725363,
#  ('16198979', 'kipps'): 248.40586966725363,
#  ('20040056', 'guddu'): 248.40586966725363,
#  ('33192532', 'hyuk'): 248.40586966725363,
#  ('9773964', 'lansky'): 248.40586966725363,
#  ('410832', 'beckett'): 248.39399811362978,
#  ('6646087', 'harper'): 248.3601383013127,
#  ('1469695', 'tim'): 248.17868603828848,
#  ('932424', 'ralphie'): 248.10589243213315,
#  ('9022958', 'estella'): 248.10589243213315,
#  ('2217387', 'kilmer'): 248.10589243213315,
#  ('30311716', 'greg'): 248.10493788351116,
#  ('10061978', 'ferris'): 248.09342699712718,
#  ('2773212', 'pooh'): 248.06726943959222,
#  ('1826422', 'richie'): 247.97089292827616,
#  ('3024239', 'shaolin'): 247.95329777352973,
#  ('10693049', 'bloom'): 247.95329777352973,
#  ('561006', 'kevin'): 247.44508621454474,
#  ('4292601', 'griffin'): 247.36287995711137,
#  ('561226', 'joel'): 247.24851455961402,
#  ('33388421', 'joseph'): 247.07162715729925,
#  ('177740', 'selina'): 246.66384703298095,
#  ('73170', 'aladdin'): 246.66384703298095,
#  ('4597853', 'andy'): 246.53908409188793,
#  ('2308701', 'paw'): 246.4618200206005,
#  ('5125674', 'ida'): 246.4618200206005,
#  ('6196826', 'jim'): 246.30739389604403,
#  ('24828951', 'dona'): 246.28365393319146,
#  ('2821645', 'stanley'): 245.93842768978536,
#  ('33674932', 'ivan'): 245.64385247698124,
#  ('4457831', 'arthur'): 245.60094288897446,
#  ('3447166', 'seymour'): 245.52843137272484,
#  ('24925008', 'quincy'): 245.4356978117063,
#  ('25737142', 'spencer'): 245.23582487592222,
#  ('10578291', 'esther'): 245.21130280384202,
#  ('22216002', 'kendrick'): 245.2083290267154,
#  ('20694087', 'shakthi'): 245.2083290267154,
#  ('3239688', 'louis'): 245.1645606519421,
#  ('4673186', 'odette'): 245.03332647477288,
#  ('3237559', 'leatherface'): 245.03332647477288,
#  ('555857', 'sylvie'): 245.03332647477288,
#  ('10049290', 'dewy'): 245.0117365757832,
#  ('13682670', 'onna'): 245.0117365757832,
#  ('1564113', 'bannion'): 245.0117365757832,
#  ('35251613', 'ermus'): 245.0117365757832,
#  ('3577764', 'tezo'): 245.0117365757832,
#  ('7261333', 'norbit'): 245.0117365757832,
#  ('9808649', 'rotti'): 245.0117365757832,
#  ('24563042', 'koldo'): 245.0117365757832,
#  ('975913', 'valek'): 245.0117365757832,
#  ('15591569', 'krechetov'): 245.0117365757832,
#  ('1985184', 'lateef'): 245.0117365757832,
#  ('27609842', 'gnomeo'): 245.0117365757832,
#  ('8138535', 'corie'): 245.0117365757832,
#  ('15851004', 'tanpopo'): 245.0117365757832,
#  ('12723089', 'neola'): 245.0117365757832,
#  ('33382022', 'kazehaya'): 245.0117365757832,
#  ('1192473', 'invid'): 245.0117365757832,
#  ('5251162', 'keld'): 245.0117365757832,
#  ('171160', 'porco'): 245.0117365757832,
#  ('75255', 'vandergroat'): 245.0117365757832,
#  ('8311612', 'wahub'): 245.0117365757832,
#  ('25244431', 'makkhi'): 245.0117365757832,
#  ('19420639', 'panche'): 245.0117365757832,
#  ('11001009', 'gilieth'): 245.0117365757832,
#  ('1434574', 'takaya'): 245.0117365757832,
#  ('2099943', 'karswell'): 245.0117365757832,
#  ('13084559', 'satyaveer'): 245.0117365757832,
#  ('24518077', 'portmann'): 245.0117365757832,
#  ('1228330', 'rebeca'): 245.0117365757832,
#  ('23233139', 'joo-yeon'): 245.0117365757832,
#  ('23207948', 'gandugali'): 245.0117365757832,
#  ('11467890', 'carrincha'): 245.0117365757832,
#  ('15002508', 'thway'): 245.0117365757832,
#  ('4059223', 'gramm'): 245.0117365757832,
#  ('29839198', 'nault'): 245.0117365757832,
#  ('254274', 'cutshaw'): 245.0117365757832,
#  ('19286149', 'desingu'): 245.0117365757832,
#  ('16839300', 'merida'): 245.0117365757832,
#  ('18423431', 'bazil'): 245.0117365757832,
#  ('31828890', 'derek'): 244.8033882317536,
#  ('20506905', 'michael'): 244.70403219980338,
#  ('8425973', 'byron'): 244.61928934861072,
#  ('377287', 'bakshi'): 244.28295977792675,
#  ('18571859', 'hachi'): 244.16764973585086,
#  ('22318957', 'turnbull'): 244.16764973585086,
#  ('8310511', 'kassim'): 244.16764973585086,
#  ('444245', 'hoffa'): 244.16764973585086,
#  ('26761606', 'miloš'): 244.16764973585086,
#  ('22475851', 'ip'): 244.16764973585086,
#  ('5274232', 'roark'): 244.16764973585086,
#  ('11140664', 'velan'): 244.16764973585086,
#  ('24808130', 'shotaro'): 244.16764973585086,
#  ('35954378', 'keira'): 244.16764973585086,
#  ('26499399', 'vinod'): 244.13339476941135,
#  ('569790', 'devlin'): 244.02139281054525,
#  ('20923240', 'rosario'): 244.02139281054525,
#  ('7548602', 'caligula'): 243.7896733969699,
#  ('6941760', 'eben'): 243.7896733969699,
#  ('2262072', 'lindbergh'): 243.7896733969699,
#  ('8360654', 'daytona'): 243.7896733969699,
#  ('8311612', 'abdul'): 243.73316606916057,
#  ('4092144', 'ricky'): 243.53344029917037,
#  ('365070', 'brigitte'): 243.46117635915752,
#  ('9629572', 'prabhu'): 243.39110043011289,
#  ('35487517', 'thor'): 243.3100056743409,
#  ('5331654', 'lindsay'): 242.86892462849758,
#  ('33096502', 'simmons'): 242.86892462849758,
#  ('4969625', 'madeline'): 242.86892462849758,
#  ('877225', 'alex'): 242.64407407045823,
#  ('27972165', 'centauri'): 242.6320452445668,
#  ('4673167', 'annika'): 242.6320452445668,
#  ('7487962', 'brownie'): 242.6320452445668,
#  ('2310825', 'rachel'): 242.54819488870527,
#  ('1099178', 'kermit'): 242.40359650161727,
#  ('24717406', 'greg'): 242.33505560715042,
#  ('950245', 'angus'): 242.29500492725177,
#  ('5623405', 'joseph'): 242.22708544833262,
#  ('18023344', 'serafina'): 242.15287407263844,
#  ...}

# %%
movies
# Out:
# {'975900': 'Ghosts of Mars',
#  '3196793': 'Getting Away with Murder: The JonBenét Ramsey Mystery',
#  '28463795': 'Brun bitter',
#  '9363483': 'White Of The Eye',
#  '261236': 'A Woman in Flames',
#  '13696889': 'The Gangsters',
#  '18998739': "The Sorcerer's Apprentice",
#  '10408933': "Alexander's Ragtime Band",
#  '9997961': 'Contigo y aquí',
#  '2345652': 'City of the Dead',
#  '175026': 'Sarah and Son',
#  '24229100': 'Lady Snowblood 2: Love Song of Vengeance',
#  '6631279': 'Little city',
#  '171005': 'Henry V',
#  '18296435': 'Aaah Belinda',
#  '11250635': 'The Mechanical Monsters',
#  '30388930': '1919',
#  '77856': 'Mary Poppins',
#  '32456683': 'Die Fahne von Kriwoj Rog',
#  '33420460': 'Keep the Change',
#  '175024': "The Devil's Holiday",
#  '612710': 'New Rose Hotel',
#  '21926710': 'White on Rice',
#  '33427105': 'Freddy and the Song of the South Pacific',
#  '31983669': 'Road to Life',
#  '17715326': 'Camera Thrills',
#  '22087420': 'Ferdinando I, re di Napoli',
#  '20604092': 'Anbu Thozhi',
#  '21344842': 'Middle Age Spread',
#  '156558': 'Baby Boy',
#  '11448183': 'Bindiya Chamkegi',
#  '9633533': 'Vandanam',
#  '31323091': 'Emilia Galotti',
#  '27611999': 'Special Effects',
#  '31025505': 'El Misterioso señor Marquina',
#  '29528534': 'Anokha Rishta',
#  '1364293': 'They Knew What They Wanted',
#  '29772142': 'Karayilekku Oru Kadal Dooram',
#  '26067101': 'Siam Sunset',
#  '26623942': 'Kausthubham',
#  '9912533': 'Cuando los duendes cazan perdices',
#  '9548445': 'Archie: To Riverdale and Back Again',
#  '32445576': 'Vinayaka Geleyara Balaga',
#  '26878691': 'Mysterious Island',
#  '10275424': 'Woman Hungry',
#  '2314463': 'Electric Apricot: Quest For Festeroo',
#  '2487170': 'Troops',
#  '25960460': 'Daddy and Them',
#  '13711159': 'The Sky Pirate',
#  '261237': 'The Gods Must Be Crazy',
#  '21153158': 'Behind The Player: John 5',
#  '14631844': 'Joan the Woman',
#  '14301436': 'Follow the Crowd',
#  '12008535': 'Rudo y Cursi',
#  '4951456': 'Kinjite: Forbidden Subjects',
#  '36009421': 'Jay Vejay',
#  '13281430': 'My Name is Fame',
#  '11633165': 'Innocence',
#  '21449578': 'Hamsun',
#  '23799443': 'Libertad bajo palabra',
#  '5708633': 'The Great New Wonderful',
#  '12053509': 'Loverboy',
#  '7252019': "Cally's Comet",
#  '3645672': 'I Fidanzati',
#  '29198000': 'Chandra Mukhi',
#  '1369204': 'Juarez',
#  '21235485': 'Mesmerized',
#  '19494009': 'Klingende toner',
#  '31323885': 'Soldat und Sportler',
#  '12371532': 'Chasing Ghosts: Beyond the Arcade',
#  '24399617': 'Bruce Lee: The Lost Interview',
#  '32104837': 'It Came Upon the Midnight Clear',
#  '20334086': 'Vipers',
#  '5915856': 'Ivar',
#  '31137877': 'Boadicea',
#  '2647998': 'The Human Tornado',
#  '21958879': "Vent'anni",
#  '1254263': 'Shivers',
#  '20944359': "Adventurer's Fate",
#  '11353896': 'Zindagi',
#  '24761154': 'My Friend Ganesha',
#  '27374355': 'Les Indiens sont encore loin',
#  '31304361': 'The Tango Player',
#  '273431': 'Terrorama',
#  '16686643': 'One Small Step: The Story of the Space Chimps',
#  '7364373': 'The Covered Wagon',
#  '31026308': 'Sombra Verde',
#  '11996174': 'Aaj Ka Andha Kanoon',
#  '7028314': 'The Little Hut',
#  '31156641': 'Nariman',
#  '32224700': 'A Romance of Wastdale',
#  '19929835': 'Aftershock: Beyond the Civil War',
#  '25413122': 'Drums in the Deep South',
#  '5664529': 'Vixen!',
#  '26776017': 'Right to Love',
#  '29832307': 'The Thirteen Chairs',
#  '24039457': 'ZA: Zombies Anonymous',
#  '31322464': 'Youth Sports Festival',
#  '5894429': 'Closing the Ring',
#  '12788657': 'The Boston Strangler',
#  '31153831': 'Neela Ponman',
#  '27556929': 'Deadly Voyage',
#  '4300418': 'The Hero: Love Story of a Spy',
#  '29766415': "Donald's Crime",
#  '30246289': '33 Scenes from Life',
#  '18109665': "The Pine's Revenge",
#  '9390791': 'Hermanas',
#  '29375144': 'The High Cost of Living',
#  '24196090': 'The World of Geisha',
#  '28028248': 'The House That Drips Blood on Alex',
#  '8669450': 'One Six Right',
#  '10419077': 'Raampur Ka Lakshman',
#  '2154704': 'Choke Canyon',
#  '28301986': 'Dig That Uranium',
#  '17780234': 'Banana Club',
#  '33059372': 'ChromeSkull: Laid to Rest 2',
#  '3740032': 'Desperate',
#  '2659373': 'The Iron Maiden',
#  '17683792': "Mighty Times: The Children's March",
#  '3873713': "Lee Dae-ro Can't Die",
#  '28415406': 'The Last Trackers of the Outback',
#  '9380065': 'Alien Express',
#  '164387': '...And Justice for All',
#  '28937087': 'Children of Glory',
#  '24282217': 'The Naked Kitchen',
#  '7443859': 'The Final Impulse',
#  '7767613': 'Star!',
#  '24863901': '1 a Minute',
#  '21373150': 'Mighty Mouse in the Great Space Chase',
#  '10792038': 'Ethe Naasaval',
#  '30002176': 'The Pagan',
#  '164388': 'The Great Santini',
#  '22985953': 'Beachhead',
#  '31723287': 'Great West End Theatres',
#  '7707787': 'Carmen',
#  '1630107': 'A Zed & Two Noughts',
#  '7572051': 'Made Men',
#  '11717027': 'Is There a Doctor in the Mouse?',
#  '22066590': 'The Bigamist',
#  '10628777': 'Peddarayudu',
#  '3550323': "Things to Do in Denver When You're Dead",
#  '1072373': 'Minsaara Kanavu',
#  '1765938': 'Convoy',
#  '7460227': 'The Bridge',
#  '19095614': 'The Castle',
#  '21878654': 'SpongeBob vs. The Big One',
#  '18902861': '14 Going on 30',
#  '26615659': 'Swati',
#  '3222645': 'The Net',
#  '20204625': "Grampy's Indoor Outing",
#  '13613357': 'Grand Canary',
#  '1305819': 'C.H.U.D.',
#  '25790807': 'Sons of Cuba',
#  '12438366': 'Mehndi Waley Hath',
#  '32229606': 'Garryowen',
#  '33495214': 'Zum Teufel mit der Penne',
#  '6752142': 'Good Morning Miss Dove',
#  '12142896': 'Emperor of the Bronx',
#  '35847891': 'White Nights',
#  '14494806': 'A Boy Named Sue',
#  '32972053': 'Broken Chains',
#  '13021375': 'The King of the Kitchen',
#  '33514209': 'Mud and Soldiers',
#  '9169526': 'Las Boludas',
#  '1031231': 'Black Cat, White Cat',
#  '9912537': 'La Delatora',
#  '27002888': 'La Marseillaise',
#  '13602366': 'The Seventh Bandit',
#  '6342767': 'The Insurgents',
#  '18524941': 'Nudist Colony of the Dead',
#  '18066159': 'The Sands of Kurobe',
#  '19031505': 'The Girl on the Pier',
#  '23666949': 'La Portatrice di pane',
#  '180917': 'Valiant Is the Word for Carrie',
#  '6305925': 'The Astronaut Farmer',
#  '196176': 'Straw Dogs',
#  '34454683': 'Agent 3S3, Massacre in the Sun',
#  '9944484': 'The Battle of Algiers',
#  '26600932': 'Oru Black And White Kudumbam',
#  '33872851': 'The Lone Wolf Meets a Lady',
#  '34702021': 'Chino',
#  '3513305': "The Weavers: Wasn't That a Time!",
#  '2509881': 'Critters 3',
#  '19569910': 'Time of Eve',
#  '12832450': 'Cipher in the snow',
#  '13091003': 'Kibera Kid',
#  '4040882': 'The World According to John Coltrane',
#  '28742538': 'City Beneath the Sea',
#  '12409066': 'Kasak',
#  '30437887': 'Thiruthalvaadi',
#  '26137128': 'The Bone Snatcher',
#  '23445121': 'No Impact Man: The Documentary',
#  '15739559': 'The Third Eye',
#  '32839744': 'Digger',
#  '34470083': 'Rollo and the Spirit of the Woods',
#  '30658112': 'The Seamstress',
#  '16304395': 'Enemy Territory',
#  '748616': 'Spring, Summer, Fall, Winter... and Spring',
#  '36151270': 'Agneekaal',
#  '33956317': 'The Catastrophe',
#  '30693170': 'Harumi',
#  '31505444': 'Blockade',
#  '336846': 'Grease',
#  '27463222': 'Vanishing on 7th Street',
#  '22256486': 'A Hundred and One Nights',
#  '3179118': 'I Clowns',
#  '3249964': 'House by the River',
#  '21906878': 'Pedro Páramo',
#  '142911': 'Thunderbolt',
#  '15007384': 'Le Grand jeu',
#  '31751930': 'Chanakya Chandragupta',
#  '23968563': 'Open All Night',
#  '11692389': 'The Snow Queen',
#  '31256008': 'Tesha',
#  '2316181': 'El derecho de nacer',
#  '6330031': 'Annie Laurie',
#  '8366514': 'Susan and God',
#  '3829646': 'What Have I Done To Deserve This?',
#  '29146560': 'The Nut',
#  '3310726': 'Yolanda and the Thief',
#  '20119316': 'Eoudong',
#  '27874961': 'The Iron Rose',
#  '3033993': 'Becoming Jane',
#  '1588008': 'Heidi Fleiss: Hollywood Madam',
#  '13291849': 'True Heart',
#  '12491178': 'A Broken Life',
#  '5696825': 'The Dark Half',
#  '6795113': 'Rettai Jadai Vayasu',
#  '30173306': 'Ab Insaf Hoga',
#  '30405742': 'Plug & Pray',
#  '32852698': 'Sinners in the Sun',
#  '254465': 'World Record',
#  '32417200': 'André and Ursula',
#  '103021': 'Midnight Express',
#  '21793185': 'Az Életbe táncoltatott leány',
#  '24011583': 'In the Name of the Fatherland',
#  '33144131': 'Fly Away',
#  '31025540': 'El Recuerdo de aquella noche',
#  '1940449': 'RoboCop 3',
#  '8973241': "Emperor's Dream",
#  '18496109': 'The Stranger',
#  '5261530': 'Carter’s Army',
#  '5384210': 'Gagamboy',
#  '6795107': 'Aval Varuvala',
#  '2174795': 'Improper Conduct',
#  '30109815': "Rogues' Regiment",
#  '73842': 'Gertie the Dinosaur',
#  '20433908': 'Adhikar',
#  '29551629': 'Tradition is a Temple',
#  '28649243': 'Martha',
#  '27365295': 'Hell Boats',
#  '6703617': 'The Forbidden Kingdom',
#  '14294670': 'Heart of the Storm',
#  '22466518': 'There It Is',
#  '20545821': 'Burning Down Tomorrow',
#  '6367133': 'Behind the Mask',
#  '21737016': "Eagle's Wing",
#  '19389755': 'Asylum Seekers',
#  '29174042': 'Toll Booth',
#  '14907363': 'The Newer Way',
#  '29851917': 'Jungle Bride',
#  '362719': 'Superman',
#  '30353952': 'Hababam Sınıfı Tatilde',
#  '2870618': 'Boy called Twist',
#  '21271533': 'Bleeder',
#  '18821340': 'Yatrik',
#  '16055450': 'If They Tell You I Fell',
#  '33870773': 'Parie',
#  '22308889': "Ken Russell's Fall of the Louse of Usher",
#  '13706555': 'The Gypsy Queen',
#  '17486320': 'Blue Pullman',
#  '7696753': 'Lord of the Flies',
#  '32148709': 'Dhan Dhana Dhan',
#  '28327554': 'The Gamblers',
#  '31156816': 'Jalothsavam',
#  '17379289': 'Without Warning',
#  '18037577': "The Pipes o' Pan",
#  '23066641': 'Rhodes of Africa',
#  '17960503': 'A Father for Brittany',
#  '13919299': 'The Devil’s Gift',
#  '10705531': 'On the Beach',
#  '4459059': 'Trial and Error',
#  '6471697': 'Ajooba',
#  '413207': 'Taxi',
#  '14886428': 'Johnny Smith and Poker-Huntas',
#  '34689049': 'A Song Goes Round the World',
#  '36542079': 'Peter schießt den Vogel ab',
#  '4069274': 'When Will I Be Loved',
#  '1643787': 'From the Drain',
#  '3681139': 'Necessary Roughness',
#  '35923481': "L'Enquête Corse",
#  '11013589': 'Der Mann im Pyjama',
#  '26205476': 'Song of the Islands',
#  '20365034': 'Mera ur kärlekens språk',
#  '33843262': 'A Friend Is a Treasure',
#  '8955475': 'Hurricane!',
#  '5685826': 'The Aviary',
#  '24234630': 'Midnight Phantom',
#  '5549065': 'Sweeney Todd: The Demon Barber of Fleet Street',
#  '14543900': 'Raju Chacha',
#  '35567084': 'I AM.',
#  '24364162': 'Nidhiyude Katha',
#  '14739568': 'Hula-La-La',
#  '37067980': 'The Lady from Peking',
#  '22644083': 'De Blanke Slavin',
#  '171058': 'Chaplin',
#  '2608958': 'Nothing to Lose',
#  '21618909': 'Barah Aana',
#  '26624119': 'Beyond the Time Barrier',
#  '6273971': 'The Prophet, the Gold and the Transylvanians',
#  '2546429': 'Friday the 13th: The Final Chapter',
#  '25947106': 'The Stoker',
#  '9916335': 'La Maestra enamorada',
#  '2596816': 'Cipher Bureau',
#  '20553214': 'Mon Mane Na',
#  '14630761': 'Mona the Virgin Nymph',
#  '34472259': 'Vášnivý bozk',
#  '3927698': 'Il Cuore nel Pozzo',
#  '31686022': "I'm Losing You",
#  '25753113': 'Wolves of the Deep',
#  '6792375': 'EMR',
#  '24416479': 'Beastmaster 2: Through the Portal of Time',
#  '31021783': 'The Gangster',
#  '14773122': 'Amy',
#  '36166216': "L'iguana dalla lingua di fuoco",
#  '1688879': 'In the Presence of a Clown',
#  '12490207': 'Over the Rainbow',
#  '20904045': 'Chala Murari Hero Banne',
#  '29468997': 'The Plastics Inventor',
#  '2574970': 'Big Wars',
#  '240088': 'In Living Color',
#  '14881706': 'The Enemy',
#  '29141182': 'Cruise for the Unknown One',
#  '32584198': 'Spiderhole',
#  '31613768': 'Hip hip hurra!',
#  '6170621': "Herod's Law",
#  '33148159': 'Lutter',
#  '12380008': 'Range Feud',
#  '16672517': 'Aap Kaa Surroor 2 - Ae Himesh Bhai!',
#  '24053482': 'Daughters',
#  '11252861': 'Akashdeep',
#  '32345990': 'Ziddi',
#  '13911991': 'A Sereia de Pedra',
#  '3883051': "National Lampoon's Class Reunion",
#  '20117139': "Susanne Brink's Arirang",
#  '34530005': 'I Will Repay',
#  '1033297': 'Resident Evil',
#  '21236198': 'Thief of Damascus',
#  '9105523': 'Picture Bride',
#  '15737392': 'Black Rider',
#  '31025770': 'La Cabeza de Pancho Villa',
#  '33519683': 'Chick Magnet',
#  '31155676': 'Anveshichu Kandethiyilla',
#  '32400923': 'My Little Pony: Twinkle Wish Adventure',
#  '25393275': 'Kodama Simham',
#  '12510319': 'Dragon Fight',
#  '17594419': 'Green Dolphin Street',
#  '207680': 'Nell',
#  '5771666': 'Hero',
#  '36422018': 'The Battle Cry of Peace',
#  '7489503': 'Keep in Style',
#  '27667647': 'Pelli Naati Pramanalu',
#  '1858682': 'Monkey Business',
#  '33006259': 'The Teacher',
#  '15221045': 'Seoul Jesus',
#  '12802045': 'The Man with the Perfect Swing',
#  '33559533': 'Dharma Seelan',
#  '7235116': 'Someone to Watch Over Me',
#  '13723442': 'Mabel, Fatty and the Law',
#  '24862266': 'Monsters Crash the Pajama Party',
#  '5254729': 'I Could Never Be Your Woman',
#  '5007743': 'Ram Aur Shyam',
#  '22695715': 'The Incident',
#  '2051395': 'The Hallelujah Trail',
#  '34858219': "A Midsummer Night's Party",
#  '15457461': 'My Baby is Black',
#  '19168185': '9 Dead Gay Guys',
#  '9124011': 'Dayman Ma`ak',
#  '11943972': 'Allonsanfàn',
#  '1393873': 'Loopy De Loop',
#  '24291753': 'The Careless Years',
#  '20648586': "Stanley Kubrick's Boxes",
#  '7447592': 'Mayerling',
#  '3865579': 'My Wild Irish Rose',
#  '14558212': 'The Spanish Jade',
#  '3959961': 'Atentat',
#  '235331': 'Red Beard',
#  '32494263': 'Amar Bondhu Rashed',
#  '8616622': 'Uproar in the Studio',
#  '34169001': 'You Never Can Tell',
#  '9560806': "Sharpe's Siege",
#  '27504492': 'Cyrano Agency',
#  '22697314': 'Inherit the Wind',
#  '1249014': 'Knife in the Water',
#  '18620635': 'The Impatient Patient',
#  '9879162': 'Gritos en la noche',
#  '35516437': 'Aasegobba Meesegobba',
#  '29513277': 'De forældreløse',
#  '35785312': 'Amador',
#  '20506905': "Perrier's Bounty",
#  '28360743': 'Fools Rush In',
#  '30624204': 'Salvage with a Smile',
#  '28178412': 'Mamarazzi',
#  '9857888': 'El Barco sale a las diez',
#  '30551885': 'Squibs',
#  '20634623': 'George and Mildred',
#  '15297854': 'CSNY Déjà Vu',
#  '35962988': 'Chhote Sarkar',
#  '31915495': 'The Magic Sword',
#  '13931033': 'O Homem Que Desafiou o Diabo',
#  '2172156': 'Kireedam',
#  '14109452': 'Crime Doctor',
#  '4783144': 'Suburban Girl',
#  '23454846': 'Is This Love?',
#  '4058835': 'Boot Polish',
#  '7583494': 'Ethan Mao',
#  '16183379': 'Fairytale of Kathmandu',
#  '24282238': 'Yamraaj',
#  '16688733': 'Live: Architecture & Morality & More',
#  '19314444': 'Heebee Jeebees',
#  '25446757': 'First Ink',
#  '2642180': 'Kadosh',
#  '24320836': 'The Shanghai Drama',
#  '12384049': 'College Coach',
#  '25019575': 'Tanging Yaman',
#  '31251203': 'Indien',
#  '15858518': 'Anbe Vaa',
#  '36448826': 'German for Kids',
#  '29016627': 'Some May Live',
#  '16572418': 'Forever',
#  '33544694': 'Dhoom 3',
#  '6004372': 'Grace of My Heart',
#  '4473622': 'Images',
#  '33639428': 'Le Cop on Le Rocks',
#  '20484431': 'City Out of Wilderness',
#  '14840648': 'The Tear That Burned',
#  '3867110': 'How They Get There',
#  '7251994': 'For Her Sake',
#  '10366326': "God's Gift to Women",
#  '1924820': 'The Seinfeld Chronicles',
#  '5418970': 'Arctic Passage',
#  '2093270': 'The Gorgon',
#  '22332882': 'The Prime of Miss Jean Brodie',
#  '22757028': 'Out: Stories of Lesbian and Gay Youth',
#  '4434585': 'Make a Little Noise',
#  '11686007': 'Sioux City',
#  '9857879': 'Estrellita',
#  '9384481': 'Count Your Blessings',
#  '22557257': 'The Moment After 2: The Awakening',
#  '8637169': 'Garage Days',
#  '30957142': 'Undercurrent',
#  '7731853': 'Laugh, Clown, Laugh',
#  '21752299': 'By Love Possessed',
#  '12091274': 'Puccini for Beginners',
#  '856733': 'A Shot in the Dark',
#  '36320373': 'Riptide',
#  '15698879': 'Meeting Se Meeting Tak',
#  '24789247': 'Half-Fare Hare',
#  '8887199': 'The Angels Wash Their Faces',
#  '28352636': '5 Lies',
#  '20018854': "It's Breaking News",
#  '76345': 'Shaft',
#  '7582987': 'The Ghost of Slumber Mountain',
#  '28858056': 'Tortura nadziei',
#  '24021571': 'Just Wright',
#  '1854612': 'Casper: A Spirited Beginning',
#  '3341998': 'Francesco, giullare di Dio',
#  '11696799': 'Breaking the Surface: The Greg Louganis Story',
#  '11463957': 'Arlington West: The Film',
#  '4926447': 'The Big Trees',
#  '20713032': 'Bhopal: Prayer for Rain',
#  '10594195': 'Betaab',
#  '25836931': 'Even the Clouds Are Drifting',
#  '1226289': 'Bless the Child',
#  '12392289': 'Mengejar Mas-Mas',
#  '21310527': 'Kizhakku Cheemayile',
#  '20579729': 'Bhagwan Parshuram',
#  '20393685': 'Secrets',
#  '19496914': 'Senza pietà',
#  '7914269': "The Letter: An American Town and the 'Somali Invasion'",
#  '29273489': 'Eyes of Youth',
#  '35987606': 'Alibaba Aradajanu Dongalu',
#  '26726624': 'Bangali Babu',
#  '22643877': 'Trouwe Kameraden',
#  '12061267': 'Grizzly II: The Predator',
#  '30351781': 'The Drums of Jeopardy',
#  '7443761': 'The Redemption of a Pal',
#  '3475071': 'The Program',
#  '3319645': 'Balseros',
#  '23688100': 'Totò e le donne',
#  '13955114': 'Hollywood Luck',
#  '2450188': 'Flesh',
#  '15945437': 'Cannibal Apocalypse',
#  '20611297': 'Pink Blue Plate',
#  '19107318': 'Crazy English',
#  '26860201': "Wolf's Clothing",
#  '34336017': 'Koko Flanel',
#  '3459253': 'Secret of the Telegian',
#  '44218': 'San Francisco',
#  '21047444': "A Girl Isn't Allowed to Love",
#  '9139404': 'Only For You',
#  '1135297': '13 Ghosts',
#  '906380': "The Emperor's Shadow",
#  '7882413': 'Aurore',
#  '31094908': 'The Living Christ Series',
#  '33773022': 'Unforgivable',
#  '20338652': 'The Dancemaker',
#  '17024723': 'The Book of Stars',
#  '18848953': 'The Shanty Where Santy Claus Lives',
#  '31638525': 'The Russian Question',
#  '19837210': 'Romasanta',
#  '30603831': 'The Beggar',
#  '9215946': 'Movie Movie',
#  '30994230': 'A Fire Has Been Arranged',
#  '29024029': 'Ente Mohangal Poovaninju',
#  '23103089': "Ray Bradbury's Chrysalis",
#  '18141105': "Get Smart's Bruce & Lloyd Out of Control",
#  '7014201': 'Ernest Goes to School',
#  '30744671': 'Men Who Have Made Love to Me',
#  '15948971': 'White Eagle',
#  '12452237': 'Heaven',
#  '15790701': 'Eagle of the Night',
#  '24732078': 'Journey',
#  '7752732': 'The Comebacks',
#  '19950563': 'The Blood Stained Route Map',
#  '11220896': 'Baba Kalyani',
#  '31457076': 'The Test',
#  '19576505': 'Dil Daulat Duniya',
#  '20271784': 'Les Bronzés font du ski',
#  '19961614': 'Misafa Lesafa',
#  '9678161': 'Maanbumigu Maanavan',
#  '13710882': 'Fatty and the Heiress',
#  '8190464': 'The Price of Rendova',
#  '31633054': 'Voodoo',
#  '20581194': 'Ganga Tera Pani Amrit',
#  '4038269': 'Before the Light Turns Green',
#  '3809621': 'Brides',
#  '19087098': 'A Waste of Shame',
#  '7082486': 'Aadavari Matalaku Ardhalu Verule',
#  '21209475': 'British Agent',
#  '20996481': 'Freelance Samurai',
#  '1957472': 'Norma Jean & Marilyn',
#  '3210963': 'Slapstick of Another Kind',
#  '9086301': 'Goldie',
#  '18300655': 'The New Dress',
#  '31196941': 'Suryaa: An Awakening',
#  '1307956': 'Stage Beauty',
#  '15890474': 'Asbury Park',
#  '20694087': 'Kanden Kadhalai',
#  '2216254': 'Jefferson in Paris',
#  '665676': 'Remembering Saddam',
#  '28530363': 'The Way',
#  '23128940': 'Arising from the Surface',
#  '10972420': 'Final Solution',
#  '23435357': 'Do Knot Disturb',
#  '30548208': 'The Iron Lady',
#  '18900393': 'Pink on the Cob',
#  '9846672': 'Loopy',
#  '29499560': 'Dawn of the Mummy',
#  '27064671': 'Four Friends',
#  '2524925': 'The Land Before Time III: The Time of the Great Giving',
#  '4002677': 'The 39 Steps',
#  '1964091': 'Next',
#  '9855335': 'Los Hombres las prefieren viudas',
#  '26687336': 'Yamla Pagla Deewana',
#  '7985961': 'The Other Side of the Door',
#  '28330207': 'Slunce, seno a pár facek',
#  '9404578': 'The Lady Vanishes',
#  '30066955': 'The Seven Sisters',
#  '30542622': 'Hattie',
#  '33726417': 'Third Halftime',
#  '34081237': 'Broadway Through a Keyhole',
#  '22056121': 'Disney Channel Games 2006',
#  '1094668': 'Asoka',
#  '7267251': 'Moonshine',
#  '6721185': 'Go Fish',
#  '3917900': 'The Contract',
#  '3899153': 'The Steamroller and the Violin',
#  '16791637': 'Love at Stake',
#  '7173668': 'Chess-Nuts',
#  '18370691': 'Sweden Live',
#  '4031676': 'Independent Lens',
#  '1028671': "Devil's Playground",
#  '27480248': 'Legends of Anika',
#  '15388340': 'A Banda das Velhas Virgens',
#  '1378672': 'Ordinary Decent Criminal',
#  '34131426': 'The Girl Without A Soul',
#  '22643691': 'Ergens in Nederland',
#  '3917891': 'The King and the Clown',
#  '30729485': 'Alice Through the Looking Glass',
#  '32789457': 'O Auto da Compadecida',
#  '24272584': 'Bala Nagamma',
#  '1641416': 'A Wild Hare',
#  '26712095': 'Cheat You Fair: The Story of Maxwell Street',
#  '7939249': 'Night Owls',
#  '22358819': 'Clash of the Titans',
#  '9962209': 'A King and His Movie',
#  '1748912': 'The Killers',
#  '9855320': 'La Guerra la gano yo',
#  '706803': 'G.I. Jane',
#  '32804099': 'Cinta Pertama',
#  '25716411': 'Typhoon Club',
#  '29508267': 'Too Outrageous!',
#  '31690131': 'Dhamarukam',
#  '5933936': 'Not Like Everyone Else',
#  '20206687': 'Never a Dull Moment',
#  '7458959': 'Old School Dos',
#  '1851703': 'Snow Falling on Cedars',
#  '9201207': 'The Thundering Herd',
#  '26283021': 'Anbirkku Alavillai',
#  '20437960': 'The Abdication',
#  '6638546': 'Deadly Outbreak',
#  '3917873': 'Chitty Chitty Bang Bang',
#  '5363369': 'Yanks',
#  '1941497': 'Kin-Dza-Dza',
#  '26890096': 'Çok Filim Hareketler Bunlar',
#  '36208311': 'Bhoomiyude Avakashikal',
#  '7266768': 'Meet Wally Sparks',
#  '14217965': 'The Ammunition Hunters',
#  '10205199': 'The Red and the White',
#  '5596675': 'TiTo',
#  '444919': 'The Redhead from Wyoming',
#  '13184162': 'Pane, amore e...',
#  '3670013': 'Harlow',
#  '2298689': 'Coney Island Baby',
#  '11599737': '26 Years Diary',
#  '17455191': 'Doppia ferita',
#  '32752081': "Abnormal Family: Older Brother's Bride",
#  '1033477': 'Godsend',
#  '29419841': 'Liar Game: The Final Stage',
#  '27498733': 'Sac de noeuds',
#  '12287578': 'Bal-Can-Can',
#  '9751550': 'Blackie the Pirate',
#  '24300269': 'Track 29',
#  '24257335': 'The Great Game',
#  '6613755': 'Bloodfist II',
#  '18848111': 'Die Feuerzangenbowle',
#  '19801670': 'The Weapon',
#  '28010827': 'Open Season 3',
#  '19036707': 'Murder in Soho',
#  '32505827': 'Dost',
#  '11467890': 'Sabata',
#  '33152192': 'Niloofar',
#  '6488515': 'Satyam Shivam Sundaram',
#  '34536797': 'Ethel',
#  '14710585': "Tanya's Island",
#  '1097249': "Don't Knock the Rock",
#  '13720943': 'Zip, the Dodger',
#  '12310718': 'Luboml: My Heart Remembers',
#  '6515754': 'A Steam Train Passes',
#  '6973699': 'And God Created Woman',
#  '7281088': 'Monster Dog',
#  '23028763': 'The Golden Spiders: A Nero Wolfe Mystery',
#  '12632216': 'The Two Worlds of Jenny Logan',
#  '23753154': 'Resin',
#  '34694618': 'Du rififi chez les femmes',
#  '21038272': 'Oru Vidukadhai Oru Thodarkadhai',
#  '33096336': 'Jeff, Who Lives at Home',
#  '5181423': 'Aar-Paar',
#  '31348830': 'Pranchiyettan and The Saint',
#  '9899642': 'Live It Up!',
#  '26068632': 'The Final Cut',
#  '21132951': 'Aparan',
#  '7154611': 'The Man in Grey',
#  '28826929': 'Guerra di Troia',
#  '33459944': 'Shakal Pe Mat Ja',
#  '7521477': "Betty Boop's May Party",
#  '21260121': 'Kickboxer 3',
#  '7026346': 'So Happy Together',
#  '4953051': 'The Bridge',
#  '22592501': 'The Eclipse',
#  '1904367': 'Das schreckliche Mädchen',
#  '28542372': 'Magyar vándor',
#  '9104619': 'Palmy Days',
#  '20695394': 'Silver Queen',
#  '34235410': 'The Amityville Haunting',
#  '21312403': 'Nenè',
#  '24207129': 'A Single Man',
#  '28400904': 'Typeface',
#  '31337689': 'The Frightened Man',
#  '18635843': 'Forgotten Refugees',
#  '31814576': 'Le Paria',
#  '25736891': 'Wrestling',
#  '22365569': 'Recovered: Journeys Through the Autism Spectrum and Back',
#  '35762859': 'Pop Class',
#  '15096320': 'Return to Babylon',
#  '11477471': 'Grateful Dead: Backstage Pass',
#  '7280802': 'Wolfman',
#  '1533733': 'The Mortal Storm',
#  '34061686': 'The Cub',
#  '13720962': "Lovers' Post Office",
#  '10706435': 'Ganga Ki Lahren',
#  '29119625': 'Canaries Sometimes Sing',
#  '5464664': 'Billy the Kid',
#  '35882350': 'Al moraheqat',
#  '32529406': 'Ninnishtam Ennishtam 2',
#  '4572965': 'Hostel 2',
#  '27290119': 'Mollenard',
#  '25897109': 'Superfantagenio',
#  '24051028': 'No Time for Sergeants',
#  '9782958': 'Deshantori',
#  '29801922': 'The Conquest',
#  '14734420': 'Pies and Guys',
#  '7536753': '10 Minutes',
#  '34525535': 'Moondru Per Moondru Kaadhal',
#  '33624347': 'Meri Biwi Ka Jawaab Nahin',
#  '8763366': 'Jekyll and Hyde... Together Again',
#  '34866550': 'Charlie at the Sydney Show',
#  '17711304': 'Rendezvous',
#  '7876902': 'Abhilasha',
#  '25847898': "Tora-san's Dream-Come-True",
#  '13293417': 'Innocent Sorcerers',
#  '9429240': 'Dharmapuri',
#  '9248665': 'The Devils Nightmare',
#  '28201876': 'Valayar Paramasivam',
#  '34366440': 'The Breath of the Gods',
#  '24009114': 'Strange Illusion',
#  '29258922': "L'Étrange Désir de monsieur Bard",
#  '28492703': 'Plašitelj kormorana',
#  '32069698': 'Diana of the Crossways',
#  '10142493': "Where's That Fire?",
#  '22644907': 'The Little Blonde Dead',
#  '9408752': 'Bastards of the Party',
#  '5774478': 'Wetback: The Undocumented Documentary',
#  '25214436': 'Apache Blood',
#  '25075517': 'If Winter Comes',
#  '31025101': 'Las mujeres mandan',
#  '1169305': 'Okinawa Rendez-vous',
#  '22378288': 'Istoria mias zois',
#  '19036329': 'The Happy Road',
#  '12771649': 'Berkeley',
#  '34319106': 'The East',
#  '20695060': 'Pink Suds',
#  '33023297': 'Seytan',
#  '17325393': 'Silk Stocking Sal',
#  '11227773': 'Wisdom of the Pretzel',
#  '24011286': 'Six-Gun Trail',
#  '9889964': 'Baaghi: A Rebel for Love',
#  '28388755': 'Nice Guy Johnny',
#  '5884079': 'Bangkok Dangerous',
#  '4633426': 'Napló apámnak, anyámnak',
#  '1781048': 'Charro!',
#  '9205349': 'Hob wa Dumoo`',
#  '29661508': 'Seenu',
#  '28024741': 'Hole in the Paper Sky',
#  '9993309': 'Deliciosamente amoral',
#  '20567826': 'Straight from the Heart',
#  '15670779': 'The House of Mirth',
#  '28736289': 'Stranger in the House',
#  '31227417': 'Boogie-Woogie Dream',
#  '17807776': 'The Magic Hour',
#  '2553539': "A Dog's Life",
#  '14709757': 'Bonanza: The Return',
#  '19247704': 'Runaway Match',
#  '10050603': 'Fancy Paradise',
#  '32956142': 'Lonely Fifteen',
#  '26900805': 'The Chiltern Hundreds',
#  '17028988': 'Nailed',
#  '8088400': 'Rey Mysterio: 619',
#  '15337014': 'The Whistle Blower',
#  '17635680': 'Young Breasts',
#  '19840260': 'Middle Sexes: Redefining He and She',
#  '36524453': 'Taj Mahal',
#  '8316526': 'Lifeguard',
#  '817057': 'Outland',
#  '34994883': 'The English Marriage',
#  '33616397': 'Yankee Doodle Pink',
#  '18053600': 'La llamada',
#  '29004995': 'Band Baaja Baaraat',
#  '9993314': 'La Culpa',
#  '1901096': 'Charles II: The Power and The Passion',
#  '399402': 'Cinderella',
#  '29302351': 'Vengayam',
#  '19134776': 'Play It Cool',
#  '19803330': 'Muallaf',
#  '31157561': 'Owd Bob',
#  '22224559': 'The Last Song',
#  '1222278': 'Vincent',
#  '9993323': 'Los Debutantes en el amor',
#  '13726036': "Fatty's Plucky Pup",
#  '15753282': 'Work In Progress',
#  '18543941': 'Toy Porno',
#  '25131827': 'And Beyond',
#  '8437284': 'Cash',
#  '937852': 'Mister Smile',
#  '7586366': 'Boys Life 5',
#  '4738976': 'Garden Isle',
#  '23346792': 'Die Jungfrau auf dem Dach',
#  '12868752': 'Futile Attraction',
#  '4200912': 'Zebra Lounge',
#  '7844547': 'Sleeping Beauties',
#  '3163300': 'Attack on Terror: The FBI vs. the Ku Klux Klan',
#  '5392217': 'Tere Ghar ke Saamne',
#  '27044179': 'The Hanged Man',
#  '22342112': 'Petersen',
#  '34624303': 'Dreamers',
#  '4836072': 'My Fair Lady',
#  '2121431': 'The House of Yes',
#  '5446828': 'Matters of Life and Death',
#  '31782747': 'Resan bort',
#  '17244218': 'Cozy Dens',
#  '32470255': 'For Those We Love',
#  '7323666': 'Gift Wrapped',
#  '35130250': 'Abdullajon',
#  '9985468': 'WWE Tagged Classics',
#  '18579003': 'The Good Companions',
#  '7922428': 'Elvis In Concert',
#  '29804533': 'Drunk Driving',
#  '5923472': 'Allari Pidugu',
#  '6644109': 'Princesas',
#  '14544711': 'Female Prisoner Scorpion: Beast Stable',
#  '35618397': 'Ghar Sansar',
#  '21426256': 'Maurie',
#  '36410662': 'Loyalties',
#  '35725115': 'Christmas Tango',
#  '9985474': 'The Committee',
#  '11361551': 'Brother Orchid',
#  '3340222': 'Day of Wrath',
#  '1132138': "It's a Very Merry Muppet Christmas Movie",
#  '11921020': 'The Corruptor',
#  '19935159': 'The Deserter',
#  '13457871': 'Father Came Too!',
#  '736262': 'The Sure Thing',
#  '5469928': 'Four Flies on Grey Velvet',
#  '4360088': "Paris, je t'aime",
#  '17369283': 'Introduction to Life',
#  '3579544': 'Afterlife',
#  '24048171': 'Marie and Bruce',
#  '34090675': 'The Perfect Roommate',
#  '23404570': "Sexual Desires in the Ladies' Restroom: Dripping!",
#  '5480947': 'Jack Smith and the Destruction of Atlantis',
#  '31322416': 'Die Jungen vom Kranichsee',
#  '17007014': 'She Learned About Sailors',
#  '34594999': 'The Tramp and the Crap Game',
#  '21088136': 'Autumn Marathon',
#  '6109092': 'The Wizard of Oz',
#  '2262277': 'Salaam Bombay!',
#  '5125134': 'Dance of the Dead',
#  '19511466': 'Rekrut 67, Petersen',
#  '5240350': 'Big Bad Mama',
#  '33412374': 'Las Vegas Bloodbath',
#  '33890738': 'Married in Canada',
#  '10624891': 'La Voltige',
#  '14076924': 'Frightmare',
#  '20138604': 'Old Sequoia',
#  '32896184': 'The Bushwhackers',
#  '32066330': 'Overheard 2',
#  '32777931': 'Wild Fruit',
#  '18195326': 'Life is Cool',
#  '30864413': 'Zaalim',
#  '13365023': 'Meu Tio Matou Um Cara',
#  '22475578': 'Sukrutham',
#  '24292756': 'Eyes of a Stranger',
#  '26446859': 'Aido: Slave of Love',
#  '24915544': 'The Green Domino',
#  '17839776': 'The Red Lily',
#  '8913767': 'Pistol Pete: The Life and Times of Pete Maravich',
#  '12677130': 'Yiddle With His Fiddle',
#  '8889869': 'Apne',
#  '21234681': 'Jud Süß',
#  '8658177': 'Wasp',
#  '7376595': 'Durval discos',
#  '414368': 'Golden Yeggs',
#  '20762723': 'The Gaucho',
#  '12095072': 'House of Cards',
#  '24434151': "Gangster's Paradise: Jerusalema",
#  '32163804': 'Murder on the Roof',
#  '23687464': 'Una Bruna indiavolata',
#  '20465302': 'The Five Cities of June',
#  '7376439': 'A Breath of Scandal',
#  '4188689': 'Emanuelle in America',
#  '10345537': 'Dil Deke Dekho',
#  '34992168': 'Trip',
#  '13113851': 'Fille du peuple',
#  '34129990': 'Bella Donna',
#  '24021186': 'Melody',
#  '30553656': 'Olave Mandhara',
#  '249406': 'Holiday Inn',
#  '7153927': 'Puppet Master 5: The Final Chapter',
#  '2295231': 'A Mom for Christmas',
#  '22994034': "A Week's Vacation",
#  '21598586': 'La Banda J.S.: Cronaca criminale del Far West',
#  '22743224': 'Bawke',
#  '8743599': 'Baazi',
#  '23687989': 'Non è vero... ma ci credo',
#  '22644468': 'Te Gek om Los te Lopen',
#  '7544443': 'Tomorrow is Forever',
#  '19160892': 'No Kidding',
#  '28379587': 'Prodaná nevěsta',
#  '7566281': 'Vallarasu',
#  '27383563': 'Looper',
#  '6242699': 'Recreation',
#  '7100124': 'Daffy Duck Slept Here',
#  '16943307': 'The Space Movie',
#  '9919006': 'Millonario por un día',
#  '30975925': 'Lady Cocoa',
#  '7567438': 'Soorma Bhopali',
#  '29154658': 'Judgment of God',
#  '22643381': 'Zuster Brown',
#  '22946282': 'A Scream from Silence',
#  '28492939': 'Alone',
#  '23248065': 'The Sky Crawlers',
#  '3694061': 'Carry On Teacher',
#  '4025965': "Chronique d'un été",
#  '17683356': 'Defending Our Lives',
#  '5445021': 'HotMen CoolBoyz',
#  '34129623': 'Sold',
#  '6847340': 'The Living Dead',
#  '17594183': 'A Shocking Accident',
#  '29278064': 'Confidential Lady',
#  '34916655': 'Second Class Citizens',
#  '6057135': 'Chu Chu and the Philly Flash',
#  '19988478': "J'ai quelque chose à vous dire",
#  '5218366': 'London Kills Me',
#  '36406869': 'Sella Turcica',
#  '27424477': 'Three Maxims',
#  '957179': 'Bright Young Things',
#  '9208103': 'Condemned to Live',
#  '30160141': 'Future Zone',
#  '3389311': 'Cadence',
#  '5565338': 'Stroker Ace',
#  '9912420': 'Caídos en el infierno',
#  '9919009': 'Una Excursión a los indios ranqueles',
#  '168571': 'Mona Lisa',
#  '31982675': 'Young People',
#  '28066754': 'Chenkol',
#  '26876259': 'Isabella',
#  '6244632': 'Crossover',
#  '26013008': 'Butterflies',
#  '6183212': 'Towed in a Hole',
#  '15941612': 'Le Mozart des Pickpockets',
#  '15371815': 'Neumi',
#  '26798968': 'Jane Steps Out',
#  '31149313': 'Paap Ka Ant',
#  '9912418': 'La Calle del pecado',
#  '846329': 'Late Spring',
#  '6352213': 'Hare Remover',
#  '19490946': 'Legends of Tanakashi: Dynasty of Blade',
#  '10990102': 'The Left Handed Gun',
#  '30719399': "It's a Grand Life",
#  '11144406': 'They Met in Bombay',
#  '1231856': 'For Love of the Game',
#  '34563800': 'Bangari',
#  '16573952': 'Virus',
#  '23737168': 'Fast Company',
#  '6602958': 'A Cool Day in August',
#  '161877': 'This Sporting Life',
#  '36036213': 'Buried Alive',
#  '24813200': 'Kisses and Caroms',
#  '36348802': 'Vulgaria',
#  '10858701': 'Cronaca di un amore',
#  '29832052': 'Brigands',
#  '9879562': 'Café Cantante',
#  '26374132': 'Lost Spring',
#  '10700127': 'Prem Parvat',
#  '934809': 'Operation Petticoat',
#  '1273569': 'The Elusive Pimpernel',
#  '30531735': 'Surviving: A Family in Crisis',
#  '31646915': 'Her First Romance',
#  '1358704': 'The Sword of Doom',
#  '1612686': 'Halloween Resurrection',
#  '10492496': 'Dizzy Pilots',
#  '23792787': 'Catita es una dama',
#  '7612646': 'First Action Hero',
#  '10663174': 'The Grind',
#  '16645962': 'Verbo',
#  '30587025': 'Devta',
#  '31707381': 'The Way to the Gold',
#  '4600837': 'The Mysterious Dr. Fu Manchu',
#  '1273572': 'Gone to Earth',
#  '8158277': 'Pussycat Dolls: Live from London',
#  '9569532': 'The Infernal Boiling Pot',
#  '77639': 'The Pride of the Yankees',
#  '28692419': 'Dead Lenny',
#  '16683731': 'Half a Dozen Babies',
#  '12395625': "Puss 'n' Boats",
#  '9879576': 'Camino al crimen',
#  '5080311': 'The Badlanders',
#  '23939272': 'Million Dollar Legs',
#  '28379461': 'U nás v Mechově',
#  '23714330': 'Passing Fancy',
#  '22145673': 'Sila Nerangalil Sila Manithargal',
#  '14415689': 'Always Tell Your Wife',
#  '5137345': 'Ninja III: The Domination',
#  '13508675': 'Blood Rage',
#  '8948959': 'The Beast of the City',
#  '29831967': 'Certo certissimo ... anzi probabile',
#  '31636280': 'Talaash',
#  '9308502': 'How to Make Use of Leisure Time: Painting',
#  '34953631': 'La Fenêtre',
#  '17470026': 'Terror Nation',
#  '9879584': 'De turno con la muerte',
#  '33404927': 'Wildness of Youth',
#  '10017049': "Don't Look Now",
#  '21686929': 'His Grace Gives Notice',
#  '309159': 'Teheran 43',
#  '27695067': 'The Mystery of Mr. X',
#  '5150761': 'Devour',
#  '10604572': 'Rebel Intruders',
#  '7378452': 'Oblivious',
#  ...}

# %%
def searchEngine_single(query, topHitsCount=10):
#     output = tfIdf.filter(lambda x : x[0][1] == query).take(10)  
    output = []
    for values in tfIdf.keys():
        if values[1] == query:
            output.append(values[0])
    ans = []
    for val in range(min(len(output), topHitsCount)):
        ans.append(movies[output[val]])
    print("Results : "+str(ans))

# %%
from scipy import spatial
def searchEngine_multiple(query, topHitsCount=10):
    qcount = {}
    for q in query:
        if q not in qcount.keys():
            qcount[q] = 1
        else:
            qcount[q]+=1
    words = []
    qVector = []
    for key, value in qcount.items():
        words.append(key)
        qVector.append(value)
 
    movieId = list(movies.keys())
    cosine = {}
    for doc in movieId:
        dVector = []
        for word in words:
            t = (doc, word)
            if t in tfIdf:
                dVector.append(tfIdf[t])
            else:
                dVector.append(0)
        s = set(dVector)
        if len(s) == 1 and 0 in s:
            continue
        result = 1 - spatial.distance.cosine(qVector, dVector)
        cosine[doc] = result
    
    sortedHits = list(sorted(cosine.items(), key=lambda item: -item[1])) # list maintains the order of sort
    sortedHits = sortedHits[0:min(len(sortedHits), topHitsCount)]
    ans=[]
    for k in range(len(sortedHits)):# getting movie names for the resultant movie ids
        temp_key = sortedHits[k][0] # movie id
        #sortedHits[k]= (movies[temp_key], sortedHits[k][1])
        ans.append(movies[temp_key])
    print("Results : "+str(ans))

# %%
query_file = spark.read.csv("/content/Queries-1.csv") # all search queries stored at first row of the csv file with delimiter','
queries=[]
for i in query_file.collect()[0]:
    queries.append([removeStopWords(i.strip().lower()),i])
for query in queries:
    print("\n")
    print('For Query "'+ query[1]+'"')
    if len(query[0])==0:
        print("Result: Query is invalid")
        continue
    
    if len(query[0])>1:
        searchEngine_multiple(query[0])
    else:
        searchEngine_single(query[0][0])
# Out:
# For Query "horror"
# Results : ['Garo: Red Requiem', 'The Last Horror Film', 'The Pagemaster', 'Microwave Massacre', 'Kiba Gaiden', 'The Pit and the Pendulum', 'Fright Night', 'Dark House', 'Poison', 'Alien invasion arizona']
#
#
# For Query "funny"
# Results : ["Garfield's Fun Fest", 'The Last Circus', 'Funny Man', '14 Carrot Rabbit', 'Ullathai Allitha', 'Bheja fry', 'Heart Like a Wheel', 'Main Sunder Hoon', 'Decoding Annie Parker', 'War Dogs']
#
#
# For Query "The heart"
# Results : ['Care Bears Movie II: A New Generation', 'The Care Bears Adventure in Wonderland', 'Crank: High Voltage', 'Captain Sindbad', 'Snow White', "Pirates of the Caribbean: At World's End", 'Bordello of Blood', 'Dragonheart: A New Beginning', '21 Grams', 'Frankenstein Conquers the World']
#
#
# For Query "Funny Movies with Action scenes"
# Results : ['The Muppets: A Celebration of 30 Years', 'Three the Hard Way', 'Megazone 23', 'Tony', "Fellini: I'm a Born Liar", 'Ullathai Allitha', 'Nell', 'Imtihaan', 'Om Shanti Om', 'My Name is Ivan']
#
#
# For Query "Fault in our stars"
# Results : ['The Secret Life of Bees', 'Pyar Hi Pyar Mein', 'How To Be', "This Girl's Life", 'Bamboozled', 'Megalodon', 'The Big One: The Great Los Angeles Earthquake', 'Prison Break: The Final Break', 'Superman', "Perrier's Bounty"]
